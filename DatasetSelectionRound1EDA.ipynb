# %%
#importing all the packages used for data analysis

import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %% [markdown]
# #Waco, Texas

# %%
import pandas as pd

# %%
waco_df  = pd.read_csv('ExecutiveInsights.Journals_WACO.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
waco_df.head(5)
# Out:
#           UniqueId  AccountId  JournalLineItemsId  ... FundGroup  Custom1 Custom2
# 0  2017-1-1-239110          1              239110  ...       NaN      NaN     NaN
# 1  2017-1-1-239111          1              239111  ...       NaN      NaN     NaN
# 2  2017-1-1-239112          1              239112  ...       NaN      NaN     NaN
# 3  2017-1-1-239113          1              239113  ...       NaN      NaN     NaN
# 4  2017-1-1-239114          1              239114  ...       NaN      NaN     NaN
#
# [5 rows x 53 columns]

# %%
waco_df = waco_df[waco_df['Actual'] != 0.0]
waco_df.tail(3)
# Out:
#                      UniqueId  AccountId  ...  Custom1 Custom2
# 2852998  2021-12-2794-3252189       2794  ...      NaN     NaN
# 2852999  2021-12-2794-3252195       2794  ...      NaN     NaN
# 2853000  2021-12-2794-3252198       2794  ...      NaN     NaN
#
# [3 rows x 53 columns]

# %%
waco_df_greater_0 = waco_df[waco_df['Actual'] > 0.0 ]
waco_df_less_0 = waco_df[waco_df['Actual'] < 0.0 ]

# %%
waco_df.shape

# %%
filtered_df = waco_df[waco_df['Actual'] > 0]

# %% [markdown]
# Questions:
#
# *   What is the effective Date?
# *   What is the difference between original and revides budget

# %% [markdown]
# Informative columns:
# *   Fund
# *   Organization
# *   AccountDescription
# *   AccountType
#
# *   Source
#
# *   SourceDescription
#
#
# *   ***Actuals***
# *   List item
#
# FiscalMonth vs EffectiveDate

# %%
waco_df['Fund'].unique()

# %%
waco_df['Organization'].unique()

# %%
waco_df.columns

# %%
waco_df['SourceDescription'].unique()

# %%
waco_df['Entity'].unique()
# Out:
# array(['City'], dtype=object)

# %%
waco_df['FiscalMonth'].unique()
# Out:
# array(['10/01/2016 12:00:00 AM', '07/01/2017 12:00:00 AM'], dtype=object)

# %%
waco_df['FiscalYear'].unique()

# %%
waco_df['EffectiveDate'].unique()

# %%
waco_df.head(10)
# Out:
#           UniqueId  AccountId  JournalLineItemsId  ... FundGroup  Custom1 Custom2
# 0  2017-1-1-239110          1              239110  ...       NaN      NaN     NaN
# 1  2017-1-1-239111          1              239111  ...       NaN      NaN     NaN
# 2  2017-1-1-239112          1              239112  ...       NaN      NaN     NaN
# 3  2017-1-1-239113          1              239113  ...       NaN      NaN     NaN
# 4  2017-1-1-239114          1              239114  ...       NaN      NaN     NaN
# 5  2017-1-1-239115          1              239115  ...       NaN      NaN     NaN
# 6  2017-1-1-239116          1              239116  ...       NaN      NaN     NaN
# 7  2017-1-1-239117          1              239117  ...       NaN      NaN     NaN
# 8  2017-1-1-239118          1              239118  ...       NaN      NaN     NaN
# 9  2017-1-1-239119          1              239119  ...       NaN      NaN     NaN
#
# [10 rows x 53 columns]

# %%
waco_df.tail(10)
# Out:
#                    UniqueId  AccountId  ...  Custom1 Custom2
# 146108  2017-10-6308-772889       6308  ...      NaN     NaN
# 146109  2017-10-6308-772890       6308  ...      NaN     NaN
# 146110  2017-10-6308-772891       6308  ...      NaN     NaN
# 146111  2017-10-6308-772892       6308  ...      NaN     NaN
# 146112  2017-10-6308-772893       6308  ...      NaN     NaN
# 146113  2017-10-6308-772975       6308  ...      NaN     NaN
# 146114  2017-10-6308-772976       6308  ...      NaN     NaN
# 146115  2017-10-6308-772977       6308  ...      NaN     NaN
# 146116  2017-10-6308-772978       6308  ...      NaN     NaN
# 146117  2017-10-6308-772979       6308  ...      NaN     NaN
#
# [10 rows x 53 columns]

# %% [markdown]
# Notes/concerns:
# Fiscal year/Fiscal month dont align with the same year:
#
# Questions:
# What is Obligated amount vs Actual
# Effective Date vs. Fiscal Month

# %% [markdown]
# metadata:
#
# *   Fiscal Month, Fiscal Year(only contains Dec 2016 and July 2017)
#
# *   Revenue: Total given by month by fical year
#
#
# *   State: TX
#
# *   Categories: 'CharacterCodeDescription', SourceDescription

# %% [markdown]
# #Parish Executive Insights

# %%
parish_df = pd.read_csv('ExecutiveInsights.Journals_PARISH.csv')
parish_df.head(5)
# Out:
#          Object  FundCode  ...  ObjectCode  JournalLineItemsId
# 0  FUND BALANCE       500  ...      210200                2150
# 1  FUND BALANCE       505  ...      210200                2152
# 2  FUND BALANCE       510  ...      210200                2154
# 3  FUND BALANCE       515  ...      210200                2156
# 4  FUND BALANCE       605  ...      210200                2158
#
# [5 rows x 53 columns]

# %%
parish_df.columns
# Out:
# Index(['Object', 'FundCode', 'FunctionGroup', 'OriginalBudget', 'FiscalYear',
#        'Segment4Code', 'Department', 'Segment7', 'OrganizationCode',
#        'Segment6', 'AccountType', 'DepartmentGroup', 'Segment5Code',
#        'FunctionDescription', 'Entity', 'Segment3', 'ProjectCode',
#        'DebitCredit', 'Segment8Code', 'Segment2', 'Segment2Code',
#        'ObligatedAmount', 'Organization', 'Segment7Code', 'RevisedBudget',
#        'Segment8', 'Project', 'Actual', 'Fund', 'FiscalMonth', 'CharacterCode',
#        'AccountId', 'Source', 'Segment4', 'Custom2', 'EffectiveDate',
#        'AccountDescription', 'UnemcumberedBalance', 'CashAccount',
#        'SourceDescription', 'UniqueId', 'FullAccount', 'FundGroup', 'Custom1',
#        'AccountStatus', 'CharacterCodeDescription', 'Segment5', 'Segment6Code',
#        'Segment3Code', 'MultiYear', 'Encumbrance', 'ObjectCode',
#        'JournalLineItemsId'],
#       dtype='object')

# %%
parish_df['FiscalMonth'].unique()
# Out:
# array(['12/01/2017 12:00:00 AM', '01/01/2018 12:00:00 AM',
#        '10/01/2018 12:00:00 AM', '11/01/2018 12:00:00 AM',
#        '12/01/2018 12:00:00 AM', '02/01/2018 12:00:00 AM',
#        '03/01/2018 12:00:00 AM', '04/01/2018 12:00:00 AM',
#        '06/01/2018 12:00:00 AM', '05/01/2018 12:00:00 AM',
#        '07/01/2018 12:00:00 AM', '08/01/2018 12:00:00 AM',
#        '09/01/2018 12:00:00 AM', '01/01/2019 12:00:00 AM'], dtype=object)

# %%
parish_df.columns
# Out:
# Index(['Object', 'FundCode', 'FunctionGroup', 'OriginalBudget', 'FiscalYear',
#        'Segment4Code', 'Department', 'Segment7', 'OrganizationCode',
#        'Segment6', 'AccountType', 'DepartmentGroup', 'Segment5Code',
#        'FunctionDescription', 'Entity', 'Segment3', 'ProjectCode',
#        'DebitCredit', 'Segment8Code', 'Segment2', 'Segment2Code',
#        'ObligatedAmount', 'Organization', 'Segment7Code', 'RevisedBudget',
#        'Segment8', 'Project', 'Actual', 'Fund', 'FiscalMonth', 'CharacterCode',
#        'AccountId', 'Source', 'Segment4', 'Custom2', 'EffectiveDate',
#        'AccountDescription', 'UnemcumberedBalance', 'CashAccount',
#        'SourceDescription', 'UniqueId', 'FullAccount', 'FundGroup', 'Custom1',
#        'AccountStatus', 'CharacterCodeDescription', 'Segment5', 'Segment6Code',
#        'Segment3Code', 'MultiYear', 'Encumbrance', 'ObjectCode',
#        'JournalLineItemsId'],
#       dtype='object')

# %%
#see which columns are in one list that are not in another list

# %% [markdown]
# *   State: Louisianna
# *  Subcategoires: Contains 'SourceDescription' Column
#
#
# *   Revenue: Given by 'Actual' column
# *   Granularity: Contains Fiscal month and Fiscal year(From Dec 2017 to Jan 2019)

# %%
parish_df.head(2)
# Out:
#          Object  FundCode  ...  ObjectCode  JournalLineItemsId
# 0  FUND BALANCE       500  ...      210200                2150
# 1  FUND BALANCE       505  ...      210200                2152
#
# [2 rows x 53 columns]

# %%
parish_df['FiscalYear'].unique()
# Out:
# array([2017, 2018, 2019, 2020, 2021, 2022])

# %%
parish_df['FiscalMonth'].unique()

# %%
parish_df['Month Number'] = parish_df['FiscalMonth'].astype(str).str[:2]
parish_df.head(2)
# Out:
#          Object  FundCode  ...  JournalLineItemsId  Month Number
# 0  FUND BALANCE       500  ...                2150            12
# 1  FUND BALANCE       505  ...                2152            12
#
# [2 rows x 54 columns]

# %%
parish_df.shape
# Out:
# (660060, 54)

# %%
filtered_par_df = parish_df[parish_df['Actual'] > 0]
filtered_par_df.shape
# Out:
# (363386, 54)

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_par_df.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number        Actual
# 0        2017           12  1.157606e+09
# 1        2018           01  1.057973e+09

# %%
agg_rev_by_month['Year-Month'] =  agg_rev_by_month['FiscalYear'].astype(str) +  '-' +  agg_rev_by_month['Month Number'].astype(str) 
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number        Actual Year-Month
# 0        2017           12  1.157606e+09    2017-12
# 1        2018           01  1.057973e+09    2018-01

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Parish County',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b0fdeb92-5395-4afa-968a-4e4e4280efd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0fdeb92-5395-4afa-968a-4e4e4280efd0")) {
#                     Plotly.newPlot(
#                         'b0fdeb92-5395-4afa-968a-4e4e4280efd0',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Pineallas County, FL',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a02ba44c-4caf-4058-be4d-9704afa491f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a02ba44c-4caf-4058-be4d-9704afa491f2")) {
#                     Plotly.newPlot(
#                         'a02ba44c-4caf-4058-be4d-9704afa491f2',
# ...

# %%
agg_Revenues_Yearly = parish_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)
# Out:
#    FiscalYear        Actual
# 0        2017  1.838112e+08
# 1        2018  4.193219e+08
# 2        2019  4.077670e+08
# 3        2020  4.059939e+08
# 4        2021  3.142438e+08
# 5        2022  1.136868e-13

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="05390af7-c367-484e-9769-95e41463a40d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("05390af7-c367-484e-9769-95e41463a40d")) {
#                     Plotly.newPlot(
#                         '05390af7-c367-484e-9769-95e41463a40d',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y= agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %% [markdown]
# #Albany, NY Dataset

# %%
albany_df = pd.read_csv('ExecutiveInsights.Journals_Albany.csv')
albany_df.head(4)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (12,16) have mixed types.Specify dtype option on import or set low_memory=False.
#                         Object FundCode  ...  ObjectCode  JournalLineItemsId
# 0                   Petty Cash        A  ...       00210           4942920.0
# 1  State and Federal Social Se        A  ...       00400           4885313.0
# 2  State and Federal Social Se        A  ...       00400           4885314.0
# 3  State and Federal Social Se        A  ...       00400           4885315.0
#
# [4 rows x 53 columns]

# %%
albany_df.shape
# Out:
# (761934, 53)

# %%
filtered_albany_df = albany_df[albany_df['Actual'] > 0]
filtered_albany_df.head(5)
# Out:
#                          Object FundCode  ...  ObjectCode  JournalLineItemsId
# 0                    Petty Cash        A  ...       00210           4942920.0
# 11  State and Federal Social Se        A  ...       00400           4942931.0
# 12  State and Federal Social Se        A  ...       00400           4963262.0
# 13  State and Federal Social Se        A  ...       00400           4979790.0
# 23        Cash In Time Deposits       CS  ...       00201           4953606.0
#
# [5 rows x 53 columns]

# %%
filtered_albany_df.shape
# Out:
# (515886, 53)

# %%
albany_df['FiscalMonth'].unique()

# %%
albany_df['Object'].unique()

# %% [markdown]
# Metadata:
# *   Subcategorization: SourceDescription, Object, Source, AccountDescription
# *   Date: Fiscal Year, FiscalMonth(jan 2018 to May 2021)
# *   Revenue: 'Actual' Column
# *   Municipality: N/A

# %%
albany_df.head(2)
# Out:
#                         Object FundCode  ...  ObjectCode  JournalLineItemsId
# 0                   Petty Cash        A  ...       00210             4942920
# 1  State and Federal Social Se        A  ...       00400             4885313
#
# [2 rows x 53 columns]

# %%
filtered_albany_df['Month Number'] = filtered_albany_df['FiscalMonth'].astype(str).str[:2]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_albany_df.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number        Actual
# 0        2018           01  3.060258e+09
# 1        2018           02  4.450174e+08

# %%
#filtered_albany_df['Month Number'] = filtered_albany_df['FiscalMonth'].astype(str).str[:2]
#agg_rev_by_month['Year'] = agg_rev_by_month['FiscalMonth'].astype(str).str[5:8]
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'].astype(str) + '-' + agg_rev_by_month['Month Number'].astype(str)

agg_rev_by_month.head(2)

#should have data scehema: Fiscalyear | Month number | Year-Month
# Out:
#    FiscalYear Month Number        Actual Year-Month
# 0        2018           01  3.060258e+09    2018-01
# 1        2018           02  4.450174e+08    2018-02

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="61af2af4-90ee-4378-b8af-62c1e0eae2da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61af2af4-90ee-4378-b8af-62c1e0eae2da")) {
#                     Plotly.newPlot(
#                         '61af2af4-90ee-4378-b8af-62c1e0eae2da',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="86c00baf-df69-42a9-a9d9-50d5fc9b2d2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86c00baf-df69-42a9-a9d9-50d5fc9b2d2b")) {
#                     Plotly.newPlot(
#                         '86c00baf-df69-42a9-a9d9-50d5fc9b2d2b',
# ...

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #CommonWealth Dataset

# %%
common_wealth_df = pd.read_csv('Commonwealth_Virginia_Revenue_Collections.csv')
common_wealth_df.head(5)
# Out:
#    Fiscal Year  ...   Revenue Source/Revenue Source Name
# 0         2017  ...  MassDOT 2010A-2 Debt Service (2154)
# 1         2018  ...  SUPPORTED EMPLOYMENT PROGRAM (1716)
# 2         2016  ...           TRUST CONTRIBUTIONS (7200)
# 3         2009  ...  RAPE PREVENTION AND EDUCATIO (1421)
# 4         2018  ...                 MISCELLANEOUS (7199)
#
# [5 rows x 21 columns]

# %% [markdown]
# What is the difference between ADP_num vs Fiscal Period

# %%
common_wealth_df.shape
# Out:
# (405637, 21)

# %%
filtered_common_wealth = common_wealth_df[common_wealth_df['Revenue Collected'] > 0]
filtered_common_wealth.shape
# Out:
# (372351, 21)

# %%
common_wealth_df.shape[0] - filtered_common_wealth.shape[0]
#we have 33, 286 rows of data that have revenue collected as less than 0. Considering the volume of this dataset I do not beleive that this should be a huge issue.
# Out:
# 33286

# %%
common_wealth_df['Fiscal Year'].min()
# Out:
# 2008

# %%
common_wealth_df['Fiscal Year'].max()
# Out:
# 2022

# %% [markdown]
# Metadata:
# *   Subcategorization: Revenue Category Name, Revenue Source/Revenue Source Name, Revenue Class Name
# *   Date: Fiscal Year, FiscalMonth(2008 to 2022), fiscal period(not sure how frequent each fiscal period is), Fiscal Month: 'APD' (Not sure what that stands for)
# *   Revenue: 'Revenue Collected' Column
# *   Municipality: N/A

# %% [markdown]
# EDA/Plotting

# %%
filtered_common_wealth.head(2)
# Out:
#    Fiscal Year  ...   Revenue Source/Revenue Source Name
# 0         2017  ...  MassDOT 2010A-2 Debt Service (2154)
# 1         2018  ...  SUPPORTED EMPLOYMENT PROGRAM (1716)
#
# [2 rows x 21 columns]

# %% [markdown]
# Need to extract the month number from the dataset given month name

# %%
filtered_common_wealth['APD_NM'].unique()
# Out:
# array(['June', 'December', 'March', 'January', 'October', 'April',
#        'August', 'May', 'July', 'September', 'February', 'November',
#        'Adjustment 3', 'Adjustment 1'], dtype=object)

# %%
filtered_common_wealth.loc[filtered_common_wealth['APD_NM'].isin(['Adjustment 3', 'Adjustment 1'])]
# Out:
#         Fiscal Year  ...                Revenue Source/Revenue Source Name
# 66             2018  ...                                      SALES (7110)
# 97             2020  ...                                       FEES (0500)
# 164            2019  ...                                   INTEREST (7100)
# 170            2016  ...                              MISCELLANEOUS (7199)
# 220            2011  ...                JOBS ACCESS/REVERSE COMMUTE (1399)
# ...             ...  ...                                               ...
# 405466         2021  ...                         PELL GRANTS 84.063 (7121)
# 405467         2021  ...  Massachusetts State Opioid Response (SOR) (FB48)
# 405482         2021  ...                              MISCELLANEOUS (7199)
# 405512         2021  ...             UNCLAIMED DEP-ABANDONED PROPER (5008)
# 405546         2021  ...                    TRANSFER- STATE LOTTERY (9043)
#
# [14610 rows x 21 columns]

# %%
#filtering out columns of 'Adjustment 1' or 'Adjustment 3'
filtered_common_wealth = filtered_common_wealth.loc[~filtered_common_wealth['APD_NM'].isin(['Adjustment 3', 'Adjustment 1'])]

# %%
filtered_common_wealth.shape
# Out:
# (357741, 21)

# %%
#creating a dictionary 
look_up = {'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05',
            'June': '06', 'July': '07', 'August': '08', 'September': '09', 'October': '10', 'November': '11', 'December': '12'}

# %%
filtered_common_wealth['Month Number'] = filtered_common_wealth['APD_NM'].apply(lambda x: look_up[x])

# %%
filtered_common_wealth.head(2)
# Out:
#    Fiscal Year  ... Month Number
# 0         2017  ...           06
# 1         2018  ...           12
#
# [2 rows x 22 columns]

# %%
#aggregate the revenue by [month, year]
agg_rev_by_month = filtered_common_wealth.groupby(['Fiscal Year', 'Month Number'], as_index = False)['Revenue Collected'].sum()
agg_rev_by_month.head(2)
# Out:
#    Fiscal Year Month Number  Revenue Collected
# 0         2008           01       4.980966e+09
# 1         2008           02       3.870727e+09

# %%
agg_rev_by_month['Year-Month'] =  agg_rev_by_month['Fiscal Year'].astype(str) +  '-' +  agg_rev_by_month['Month Number'].astype(str) 
agg_rev_by_month.head(2)
# Out:
#    Fiscal Year Month Number  Revenue Collected Year-Month
# 0         2008           01       4.980966e+09    2008-01
# 1         2008           02       3.870727e+09    2008-02

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Revenue Collected'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month CommonWealth, VA',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d56f8713-22ba-40f4-ba61-0b2afc306d9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d56f8713-22ba-40f4-ba61-0b2afc306d9c")) {
#                     Plotly.newPlot(
#                         'd56f8713-22ba-40f4-ba61-0b2afc306d9c',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Revenue Collected'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in CommonWealth, VA',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="881ddffa-b67b-4ad2-a356-c0e698d2acb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("881ddffa-b67b-4ad2-a356-c0e698d2acb1")) {
#                     Plotly.newPlot(
#                         '881ddffa-b67b-4ad2-a356-c0e698d2acb1',
# ...

# %%
agg_Revenues_Yearly = filtered_common_wealth.groupby('Fiscal Year', as_index= False)['Revenue Collected'].sum()
agg_Revenues_Yearly.head(2)
# Out:
#    Fiscal Year  Revenue Collected
# 0         2008       5.899712e+10
# 1         2009       6.153121e+10

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['Fiscal Year'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Revenue Collected'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9c84717c-09c9-4248-b2ec-12b03f9a0b88" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c84717c-09c9-4248-b2ec-12b03f9a0b88")) {
#                     Plotly.newPlot(
#                         '9c84717c-09c9-4248-b2ec-12b03f9a0b88',
# ...

# %% [markdown]
# Not sure why there is a time period of no data/Might be due to the 'Adjustment 3' and 'Adjustment 1' columns that we got rid of

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y= "Revenue Collected", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Fiscal Year", y="Revenue Collected", data = agg_Revenues_Yearly)

# %% [markdown]
# #Nola Dataset

# %%
nola_df = pd.read_csv('NOLA_Sales_Tax_Revenues_To_The_City_s_General_Fund__2003_-_Present_.csv')

# %%
nola_df.head(10)
# Out:
#                                                RowID  ...  IndicatorValue
# 0  Sales tax revenues to the City's General Fund2011  ...       153955000
# 1  Sales tax revenues to the City's General Fund2005  ...       116339000
# 2  Sales tax revenues to the City's General Fund2009  ...       133868000
# 3  Sales tax revenues to the City's General Fund2007  ...       134114000
# 4  Sales tax revenues to the City's General Fund2004  ...       153851000
# 5  Sales tax revenues to the City's General Fund2006  ...       124229000
# 6  Sales tax revenues to the City's General Fund2010  ...       147453000
# 7  Sales tax revenues to the City's General Fund2013  ...       176465000
# 8  Sales tax revenues to the City's General Fund2012  ...       163128000
# 9  Sales tax revenues to the City's General Fund2008  ...       137581000
#
# [10 rows x 5 columns]

# %%
nola_df.dtypes
# Out:
# RowID             object
# Year               int64
# Date              object
# IndicatorName     object
# IndicatorValue     int64
# dtype: object

# %%
nola_df.Year.min()
# Out:
# 2003

# %%
nola_df.Year.max()
# Out:
# 2014

# %%
nola_df['Date'].unique()
# Out:
# array(['01/01/2011 12:00:00 AM', '01/01/2005 12:00:00 AM',
#        '01/01/2009 12:00:00 AM', '01/01/2007 12:00:00 AM',
#        '01/01/2004 12:00:00 AM', '01/01/2006 12:00:00 AM',
#        '01/01/2010 12:00:00 AM', '01/01/2013 12:00:00 AM',
#        '01/01/2012 12:00:00 AM', '01/01/2008 12:00:00 AM',
#        '01/01/2014 12:00:00 AM', '01/01/2003 12:00:00 AM'], dtype=object)

# %% [markdown]
# We are only given yearly data, hard to forecast with

# %% [markdown]
# Metadata:
# *   Subcategorization: N/a
# *   Date: Only by year( 2003-2014
# *   Revenue: 'Indicator Value' column
# *   Municipality: N/A

# %% [markdown]
# #Pineallas

# %%
import pandas as pd

# %%
pineallas = pd.read_csv('Pinellas_County_Florida.csv')

# %%
pineallas.shape
# Out:
# (169, 13)

# %%
pineallas.head(10)
# Out:
#    RowID  Department ID  ...        Value  Comments
# 0    168             16  ...   5778833.99       NaN
# 1    186             16  ...         3.00       NaN
# 2    167             16  ...   4188408.16       NaN
# 3    169             16  ...   9679139.95       NaN
# 4     12             16  ...         2.40       NaN
# 5     64             16  ...         3.30       NaN
# 6     83             16  ...        98.03       NaN
# 7     55             16  ...         2.50       NaN
# 8     60             16  ...   4282463.00       NaN
# 9      6             16  ...  69890368.00       NaN
#
# [10 rows x 13 columns]

# %%
pineallas['Measure Title'].unique()
# Out:
# array(['Bed Tax Collected', 'Average Days Spent by Visitors',
#        'Visitor Spending Dollars Returned to Pinellas County Businesses for Every 1 Dollar Invested in VSPC Marketing',
#        'Average Nights Spent by Visitors', 'Visitor Count',
#        'Sales Tax Revenue', 'Direct Visitor Spending',
#        'Number of Hotel Room Nights Resulting from Sales and Marketing Initiatives in the Meetings Market',
#        'Hotel Room Nights',
#        'Economic Impact Generated from Visit St Pete Clearwater Website',
#        'County Taxes Paid by Visitors', 'Investment in Marketing',
#        'County Taxes Paid by Visitors Attributed to Marketing',
#        'Number of Hotel Room Nights Resulting from Sales and Marketing Initiatives in the Sports Market',
#        'Visitor Spending Attributed to Marketing',
#        'Marketing Communications Recall',
#        'Tax Dollars Returned to Pinellas County Government for Every 1 Dollar Invested in VSPC Marketing'],
#       dtype=object)

# %%
pineallas[pineallas['Measure Title'] == 'Sales Tax Revenue'].head(20)
# Out:
#      RowID  Department ID  ...        Value  Comments
# 9        6             16  ...   69890368.0       NaN
# 17      16             16  ...   71132456.0       NaN
# 40      37             16  ...   59869465.0       NaN
# 48      51             16  ...   93716593.0       NaN
# 55      40             16  ...   60610992.0       NaN
# 65     206             16  ...   85666313.0       NaN
# 88      15             16  ...   75842101.0       NaN
# 99      93             16  ...   74800204.0       NaN
# 106    142             16  ...   51615606.0       NaN
# 117     58             16  ...   90271569.0       NaN
# 123    161             16  ...   47955098.0       NaN
# 133    109             16  ...   87617689.0       NaN
# 135     74             16  ...   73071779.0       NaN
# 139    191             16  ...  100244986.0       NaN
# 141    177             16  ...   82903558.0       NaN
# 149    123             16  ...   31942357.0       NaN
#
# [16 rows x 13 columns]

# %% [markdown]
# There are only 16 rows of data after filtering Measure Title by Sales Tax Revenue

# %%
pineallas_sales_tax_df = pineallas[pineallas['Measure Title'] == 'Sales Tax Revenue']

# %%
pineallas_sales_tax_df.shape
# Out:
# (16, 13)

# %%
pineallas_sales_tax_df['Date'].unique()
# Out:
# array(['12/31/2017 12:00:00 AM', '06/30/2018 12:00:00 AM',
#        '09/30/2018 12:00:00 AM', '03/31/2019 12:00:00 AM',
#        '12/31/2018 12:00:00 AM', '09/30/2021 12:00:00 AM',
#        '03/31/2018 12:00:00 AM', '12/31/2019 12:00:00 AM',
#        '09/30/2020 12:00:00 AM', '06/30/2019 12:00:00 AM',
#        '12/31/2020 12:00:00 AM', '03/31/2020 12:00:00 AM',
#        '09/30/2019 12:00:00 AM', '06/30/2021 12:00:00 AM',
#        '03/31/2021 12:00:00 AM', '06/30/2020 12:00:00 AM'], dtype=object)

# %%
pineallas_sales_tax_df

# %% [markdown]
# When filtering out only the 'Sales Tax Revenue

# %%
pineallas.columns
# Out:
# Index(['RowID', 'Department ID', 'Department Name', 'Division ID',
#        'Division Name', 'MeasureID', 'Measure Title',
#        'DataCollection Frequency', 'Unit Name', 'DataCollection Start Date',
#        'Date', 'Value', 'Comments'],
#       dtype='object')

# %%
pineallas['Unit Name'].unique()
#What does count and percent mean
# Out:
# array(['US Dollars', 'Count', 'Percent'], dtype=object)

# %%
pineallas['Comments'].unique()
# Out:
# array([nan, 'Interim Findings'], dtype=object)

# %%
pineallas[pineallas['Comments'] == 'Interim Findings']
# Out:
#      RowID  Department ID  ... Value          Comments
# 156    136             16  ... -59.9  Interim Findings
#
# [1 rows x 13 columns]

# %%
pineallas[pineallas['Value'] <0 ]
# Out:
#      RowID  Department ID  ... Value          Comments
# 156    136             16  ... -59.9  Interim Findings
#
# [1 rows x 13 columns]

# %% [markdown]
# Metadata:
# *   Subcategorization: Department Name,Division Name, Measure Title
# *   Date: Date Column, Data Collection Frequency
# *   Revenue: 'Value' Column
# *   Municipality: N/A

# %% [markdown]
# After filtering the mearure title for only Sales Tax Revenue, we only have quarterly data

# %% [markdown]
# Notes:
# Data collection Frequency, do different departments measure data collection frequency differently
#
# For our purposes, we could only filter out the ones that are colectted monthly, but wouldnt be a very representative model.
#
# We dont really care about the DataCollection Start data model

# %% [markdown]
# EDA- Pineallas

# %%
pineallas.head(2)
# Out:
#    RowID  Department ID  ...       Value  Comments
# 0    168             16  ...  5778833.99       NaN
# 1    186             16  ...        3.00       NaN
#
# [2 rows x 13 columns]

# %%
#EDA for Pineallas
monthly_filtered = pineallas[pineallas['DataCollection Frequency'] == 'Monthly']
monthly_filtered.shape
# Out:
# (30, 13)

# %%
monthly_filtered.head(10)
# Out:
#     RowID  Department ID  ...       Value  Comments
# 0     168             16  ...  5778833.99       NaN
# 2     167             16  ...  4188408.16       NaN
# 3     169             16  ...  9679139.95       NaN
# 12    183             16  ...  7697344.00       NaN
# 14    182             16  ...  8749606.38       NaN
# 23    184             16  ...  8273409.29       NaN
# 25    114             16  ...   516029.00       NaN
# 34    197             16  ...  8581849.00       NaN
# 35    198             16  ...  5223033.16       NaN
# 36    100             16  ...  7532078.00       NaN
#
# [10 rows x 13 columns]

# %%
monthly_filtered.tail(10)
# Out:
#      RowID  Department ID  ...       Value  Comments
# 72      53             16  ...  5352499.00       NaN
# 78      86             16  ...  4554786.00       NaN
# 87     152             16  ...  3472276.33       NaN
# 90     129             16  ...  4192583.00       NaN
# 91      84             16  ...  4088933.00       NaN
# 95     199             16  ...  4488471.42       NaN
# 103     52             16  ...  6732633.00       NaN
# 111    115             16  ...  2243798.00       NaN
# 119    116             16  ...  4256609.00       NaN
# 130     85             16  ...  3989907.00       NaN
#
# [10 rows x 13 columns]

# %%
#Date column always occurs at the end of the month

# %%
monthly_filtered['Date'].unique()
# Out:
# array(['02/28/2021 12:00:00 AM', '01/31/2021 12:00:00 AM',
#        '03/31/2021 12:00:00 AM', '05/31/2021 12:00:00 AM',
#        '04/30/2021 12:00:00 AM', '06/30/2021 12:00:00 AM',
#        '04/30/2020 12:00:00 AM', '07/31/2021 12:00:00 AM',
#        '08/31/2021 12:00:00 AM', '02/29/2020 12:00:00 AM',
#        '11/30/2020 12:00:00 AM', '08/31/2019 12:00:00 AM',
#        '09/30/2019 12:00:00 AM', '08/31/2020 12:00:00 AM',
#        '07/31/2019 12:00:00 AM', '06/30/2019 12:00:00 AM',
#        '12/31/2020 12:00:00 AM', '01/31/2020 12:00:00 AM',
#        '09/30/2020 12:00:00 AM', '03/31/2020 12:00:00 AM',
#        '05/31/2019 12:00:00 AM', '12/31/2019 12:00:00 AM',
#        '10/31/2020 12:00:00 AM', '07/31/2020 12:00:00 AM',
#        '10/31/2019 12:00:00 AM', '09/30/2021 12:00:00 AM',
#        '04/30/2019 12:00:00 AM', '05/31/2020 12:00:00 AM',
#        '06/30/2020 12:00:00 AM', '11/30/2019 12:00:00 AM'], dtype=object)

# %%
monthly_filtered['Month Number'] = monthly_filtered['Date'].astype(str).str[:2] 
monthly_filtered['Year'] = monthly_filtered['Date'].astype(str).str[6:10] 

monthly_filtered.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    RowID  Department ID  ... Month Number  Year
# 0    168             16  ...           02  2021
# 2    167             16  ...           01  2021
#
# [2 rows x 15 columns]

# %%
agg_rev_by_month = monthly_filtered.groupby(['Year', 'Month Number'], as_index= False)['Value'].sum()
agg_rev_by_month.head(2)
# Out:
#    Year Month Number      Value
# 0  2019           04  6732633.0
# 1  2019           05  5352499.0

# %%
agg_rev_by_month['Year-Month'] =  agg_rev_by_month['Year'].astype(str) +  '-' +  agg_rev_by_month['Month Number'].astype(str).str[-2:] 
agg_rev_by_month.head(2)
# Out:
#    Year Month Number      Value Year-Month
# 0  2019           04  6732633.0    2019-04
# 1  2019           05  5352499.0    2019-05

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Value'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Pineallas County',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81c4be34-81d3-43bb-88da-c76a76eb246f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81c4be34-81d3-43bb-88da-c76a76eb246f")) {
#                     Plotly.newPlot(
#                         '81c4be34-81d3-43bb-88da-c76a76eb246f',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Value'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Pineallas County, FL',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1cbf167-2599-4af1-82dc-cb4feac2dcf5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1cbf167-2599-4af1-82dc-cb4feac2dcf5")) {
#                     Plotly.newPlot(
#                         'a1cbf167-2599-4af1-82dc-cb4feac2dcf5',
# ...

# %%
pineallas.head(2)
# Out:
#    RowID  Department ID  ...       Value  Comments
# 0    168             16  ...  5778833.99       NaN
# 1    186             16  ...        3.00       NaN
#
# [2 rows x 13 columns]

# %%
pineallas['Year'] = pineallas['Date'].astype(str).str[6:10]
pineallas.head(2)
# Out:
#    RowID  Department ID  ... Comments  Year
# 0    168             16  ...      NaN  2021
# 1    186             16  ...      NaN  2021
#
# [2 rows x 14 columns]

# %%
agg_Revenues_Yearly = pineallas.groupby('Year', as_index= False)['Value'].sum()
agg_Revenues_Yearly.head(10)
# Out:
#    Year         Value
# 0  2017  1.512010e+09
# 1  2018  7.877020e+09
# 2  2019  8.420399e+09
# 3  2020  5.605357e+09
# 4  2021  4.526647e+09

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['Year'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Value'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43582ed5-1ca8-4e0f-8fe4-8cd1ea68e587" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43582ed5-1ca8-4e0f-8fe4-8cd1ea68e587")) {
#                     Plotly.newPlot(
#                         '43582ed5-1ca8-4e0f-8fe4-8cd1ea68e587',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_Revenues_Yearly['Year'].astype(dtype=str), 
                        y= agg_Revenues_Yearly['Value'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7674a163-2186-48c1-bfdf-8fc59f2d03f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7674a163-2186-48c1-bfdf-8fc59f2d03f6")) {
#                     Plotly.newPlot(
#                         '7674a163-2186-48c1-bfdf-8fc59f2d03f6',
# ...

# %% [markdown]
# #Nassau

# %%
nassau_ny = pd.read_csv('Nasssau_NewYork_Sales_Tax__Assessed_Value_and_Estimated_Actual_Value_of_Taxable_Property.csv')
nassau_ny.head(10)
# Out:
#               Fiscal Year  ...  Sales Tax Revenues Adjusted for Thousands
# 0  12/31/2020 12:00:00 AM  ...                                 1164165000
# 1  12/31/2019 12:00:00 AM  ...                                 1242220000
# 2  12/31/2018 12:00:00 AM  ...                                 1194466000
# 3  12/31/2017 12:00:00 AM  ...                                 1151393000
# 4  12/31/2016 12:00:00 AM  ...                                 1124085000
# 5  12/31/2015 12:00:00 AM  ...                                 1102886000
# 6  12/31/2014 12:00:00 AM  ...                                 1090809000
# 7  12/31/2013 12:00:00 AM  ...                                 1135245000
# 8  12/31/2012 12:00:00 AM  ...                                 1066011000
# 9  12/31/2011 12:00:00 AM  ...                                 1023128000
#
# [10 rows x 13 columns]

# %%
nassau_ny.shape
# Out:
# (13, 13)

# %%
nassau_ny['Sales Tax Revenue'].sort_values(ascending = False)
# Out:
# 1     1242220
# 2     1194466
# 0     1164165
# 3     1151393
# 7     1135245
# 4     1124085
# 5     1102886
# 6     1090809
# 8     1066011
# 9     1023128
# 12     998733
# 10     997175
# 11     949710
# Name: Sales Tax Revenue, dtype: int64

# %%
nassau_ny['Fiscal Year'].unique()
# Out:
# array(['12/31/2020 12:00:00 AM', '12/31/2019 12:00:00 AM',
#        '12/31/2018 12:00:00 AM', '12/31/2017 12:00:00 AM',
#        '12/31/2016 12:00:00 AM', '12/31/2015 12:00:00 AM',
#        '12/31/2014 12:00:00 AM', '12/31/2013 12:00:00 AM',
#        '12/31/2012 12:00:00 AM', '12/31/2011 12:00:00 AM',
#        '12/31/2010 12:00:00 AM', '12/31/2009 12:00:00 AM',
#        '12/31/2008 12:00:00 AM'], dtype=object)

# %% [markdown]
# Only has yearly sales tax revenue, no point in exploring further.

# %% [markdown]
# #Baton Rogue, Louisianna

# %%
baton_la = pd.read_csv('Baton_Rogue_LA_Sales_Tax_Collections.csv')
baton_la.head(10)
# Out:
#        ID  ...  CITY-PARISH TOTAL TAX COLLECTIONS
# 0  202109  ...                           20000353
# 1  202108  ...                           17846830
# 2  202107  ...                           18701987
# 3  202106  ...                           19830525
# 4  202105  ...                           18059895
# 5  202104  ...                           18461102
# 6  202103  ...                           19743231
# 7  202102  ...                           14737346
# 8  202101  ...                           15934495
# 9  202012  ...                           19010537
#
# [10 rows x 12 columns]

# %%
baton_la.head(10)
# Out:
# 20000353

# %%
baton_la.tail(10)
# Out:
#          ID  ...  CITY-PARISH TOTAL TAX COLLECTIONS
# 131  201010  ...                           12551100
# 132  201009  ...                           12859476
# 133  201008  ...                           13054566
# 134  201007  ...                           12525611
# 135  201006  ...                           13395492
# 136  201005  ...                           12545680
# 137  201004  ...                           13116866
# 138  201003  ...                           14204819
# 139  201002  ...                           11827010
# 140  201001  ...                           11891026
#
# [10 rows x 12 columns]

# %%
baton_la.shape
# Out:
# (141, 12)

# %%
baton_la.dtypes
# Out:
# ID                                                   int64
# YEAR                                                 int64
# MONTH                                               object
# CITY TAX COLLECTIONS (NON-VEHICLE SALES)             int64
# CITY VEHICLE SALES TAX COLLECTIONS                   int64
# CITY TOTAL TAX COLLECTIONS                           int64
# PARISH TAX COLLECTIONS (NON-VEHICLE SALES TAXES)     int64
# PARISH VEHICLE TAX COLLECTIONS                       int64
# PARISH TOTAL TAX COLLECTIONS                         int64
# CITY-PARISH TOTAL (NON-VEHICLE SALES TAXES)          int64
# CITY-PARISH VEHICLE SALES TAX COLLECTIONS            int64
# CITY-PARISH TOTAL TAX COLLECTIONS                    int64
# dtype: object

# %%
baton_la['YEAR'].max()
# Out:
# 2021

# %%
baton_la['YEAR'].min()
# Out:
# 2010

# %%
baton_la.columns
# Out:
# Index(['ID', 'YEAR', 'MONTH', 'CITY TAX COLLECTIONS (NON-VEHICLE SALES)',
#        'CITY VEHICLE SALES TAX COLLECTIONS', 'CITY TOTAL TAX COLLECTIONS',
#        'PARISH TAX COLLECTIONS (NON-VEHICLE SALES TAXES)',
#        'PARISH VEHICLE TAX COLLECTIONS', 'PARISH TOTAL TAX COLLECTIONS',
#        'CITY-PARISH TOTAL (NON-VEHICLE SALES TAXES)',
#        'CITY-PARISH VEHICLE SALES TAX COLLECTIONS',
#        'CITY-PARISH TOTAL TAX COLLECTIONS'],
#       dtype='object')

# %%
baton_la.isnull().sum()
#no null values exist
# Out:
# ID                                                  0
# YEAR                                                0
# MONTH                                               0
# CITY TAX COLLECTIONS (NON-VEHICLE SALES)            0
# CITY VEHICLE SALES TAX COLLECTIONS                  0
# CITY TOTAL TAX COLLECTIONS                          0
# PARISH TAX COLLECTIONS (NON-VEHICLE SALES TAXES)    0
# PARISH VEHICLE TAX COLLECTIONS                      0
# PARISH TOTAL TAX COLLECTIONS                        0
# CITY-PARISH TOTAL (NON-VEHICLE SALES TAXES)         0
# CITY-PARISH VEHICLE SALES TAX COLLECTIONS           0
# CITY-PARISH TOTAL TAX COLLECTIONS                   0
# dtype: int64

# %%
baton_la
# Out:
#          ID  ...  CITY-PARISH TOTAL TAX COLLECTIONS
# 0    202109  ...                           20000353
# 1    202108  ...                           17846830
# 2    202107  ...                           18701987
# 3    202106  ...                           19830525
# 4    202105  ...                           18059895
# ..      ...  ...                                ...
# 136  201005  ...                           12545680
# 137  201004  ...                           13116866
# 138  201003  ...                           14204819
# 139  201002  ...                           11827010
# 140  201001  ...                           11891026
#
# [141 rows x 12 columns]

# %%
baton_la_filtered = baton_la[['ID', 'YEAR', 'MONTH', 'CITY-PARISH TOTAL TAX COLLECTIONS']]
baton_la_filtered.head(2)
# Out:
#        ID  YEAR      MONTH  CITY-PARISH TOTAL TAX COLLECTIONS
# 0  202109  2021  September                           20000353
# 1  202108  2021     August                           17846830

# %%
baton_la_filtered['Month Number'] = baton_la_filtered['ID'].astype(str).str[-2:]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
baton_la_filtered.head(2)
# Out:
#        ID  YEAR      MONTH  CITY-PARISH TOTAL TAX COLLECTIONS Month Number
# 0  202109  2021  September                           20000353           09
# 1  202108  2021     August                           17846830           08

# %%
agg_rev_by_month = baton_la_filtered.groupby(['YEAR', 'Month Number'], as_index= False)['CITY-PARISH TOTAL TAX COLLECTIONS'].sum()
agg_rev_by_month.head(2)
# Out:
#    YEAR Month Number  CITY-PARISH TOTAL TAX COLLECTIONS
# 0  2010           01                           11891026
# 1  2010           02                           11827010

# %%
agg_rev_by_month['Year-Month'] =  agg_rev_by_month['YEAR'].astype(str) +  '-' +  agg_rev_by_month['Month Number'].astype(str).str[-2:] 
agg_rev_by_month.head(2)
# Out:
#    YEAR Month Number  CITY-PARISH TOTAL TAX COLLECTIONS Year-Month
# 0  2010           01                           11891026    2010-01
# 1  2010           02                           11827010    2010-02

# %%
agg_rev_by_month.head(10)
# Out:
#    YEAR Month Number  CITY-PARISH TOTAL TAX COLLECTIONS Year-Month
# 0  2010           01                           11891026    2010-01
# 1  2010           02                           11827010    2010-02
# 2  2010           03                           14204819    2010-03
# 3  2010           04                           13116866    2010-04
# 4  2010           05                           12545680    2010-05
# 5  2010           06                           13395492    2010-06
# 6  2010           07                           12525611    2010-07
# 7  2010           08                           13054566    2010-08
# 8  2010           09                           12859476    2010-09
# 9  2010           10                           12551100    2010-10

# %% [markdown]
# Why does the month number not match with the 'Yaer-Month' column

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['CITY-PARISH TOTAL TAX COLLECTIONS'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Month',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf7ed70d-0a27-439c-a1d0-5c699785e162" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf7ed70d-0a27-439c-a1d0-5c699785e162")) {
#                     Plotly.newPlot(
#                         'cf7ed70d-0a27-439c-a1d0-5c699785e162',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['CITY-PARISH TOTAL TAX COLLECTIONS'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Month in Baton Rogue, LA',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f3e7fc2-661c-415f-a965-d139e15c18af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f3e7fc2-661c-415f-a965-d139e15c18af")) {
#                     Plotly.newPlot(
#                         '8f3e7fc2-661c-415f-a965-d139e15c18af',
# ...

# %%
baton_la.head(1)
# Out:
#        ID  ...  CITY-PARISH TOTAL TAX COLLECTIONS
# 0  202109  ...                           20000353
#
# [1 rows x 12 columns]

# %%
agg_Revenues_Yearly = baton_la.groupby('YEAR', as_index= False)['CITY-PARISH TOTAL TAX COLLECTIONS'].sum()
agg_Revenues_Yearly.head(10)
# Out:
#    YEAR  CITY-PARISH TOTAL TAX COLLECTIONS
# 0  2010                          156290835
# 1  2011                          162542521
# 2  2012                          172786549
# 3  2013                          174834102
# 4  2014                          180040865
# 5  2015                          185007960
# 6  2016                          195444560
# 7  2017                          194864665
# 8  2018                          192115740
# 9  2019                          195385108

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['YEAR'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['CITY-PARISH TOTAL TAX COLLECTIONS'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30d04019-27aa-4dd4-9b01-b661ed838ca2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30d04019-27aa-4dd4-9b01-b661ed838ca2")) {
#                     Plotly.newPlot(
#                         '30d04019-27aa-4dd4-9b01-b661ed838ca2',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_Revenues_Yearly['YEAR'].astype(dtype=str), 
                        y= agg_Revenues_Yearly['CITY-PARISH TOTAL TAX COLLECTIONS'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0d4646a6-8aed-4422-add7-ec9214ef8814" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d4646a6-8aed-4422-add7-ec9214ef8814")) {
#                     Plotly.newPlot(
#                         '0d4646a6-8aed-4422-add7-ec9214ef8814',
# ...

# %% [markdown]
# Metadata:
# *   Subcategorization: Breaks down Total Sales Tax Revenue in Columns of subcategories
# *   Date: 'Year', 'Month'(Jan 2010 to Sept 2021)
# *   Revenue: Multiple columns of subcategories of revenue
# *   Municipality: City, City-Parish, Parish(Not sure of differences)

# %% [markdown]
# #Conneticut

# %%
conneticut_df = pd.read_csv('Conneticut_Tax_Revenue_By_Month.csv')
conneticut_df.head(10)
# Out:
#        Month  Calendar Year  ... Beverage Container Deposits  Total Revenue
# 0       July           2011  ...                         NaN   3.058430e+07
# 1     August           2011  ...                   144726.50   7.246003e+08
# 2  September           2011  ...                    64361.03   1.203827e+09
# 3    October           2011  ...                  7240241.36   1.266111e+09
# 4   November           2011  ...                   152895.02   1.004029e+09
# 5   December           2011  ...                        0.00   1.273327e+09
# 6    January           2012  ...                  6119382.24   1.859609e+09
# 7   February           2012  ...                   148897.63   1.021146e+09
# 8      March           2012  ...                    -1048.61   1.205020e+09
# 9      April           2012  ...                  5334617.33   2.511615e+09
#
# [10 rows x 51 columns]

# %% [markdown]
# EDA:
#
# 1.   getting summation(vertical) of values for each column, average, quantiles
# 2.   Getting total revenue by month(seasonality)
# 3.   Getting total revenue over time(by month)
# 4.   Getting total revenue yearly

# %%
import numpy as np

#getting statistical data of breakdown of categories grouped by year
#conneticut_df.groupby('Calendar Year').agg([np.mean, np.sum, np.median,  np.min, np.max])

# %%
grouped_df = conneticut_df.groupby(['Calendar Year', 'Month']).agg([np.mean, np.sum, np.median,  np.min, np.max])
grouped_df.head(5)
# Out:
#                          Withholding                ... Total Revenue
#                                 mean           sum  ...          amin          amax
# Calendar Year Month                                 ...
# 2011          August    2.771524e+08  2.771524e+08  ...  7.246003e+08  7.246003e+08
#               December  5.409526e+08  5.409526e+08  ...  1.273327e+09  1.273327e+09
#               July               NaN  0.000000e+00  ...  3.058430e+07  3.058430e+07
#               November  4.657074e+08  4.657074e+08  ...  1.004029e+09  1.004029e+09
#               October   4.086132e+08  4.086132e+08  ...  1.266111e+09  1.266111e+09
#
# [5 rows x 240 columns]

# %%
grouped_df.columns = grouped_df.columns.map(' '.join)
grouped_df.head(2)
# Out:
#                         Withholding mean  ...  Total Revenue amax
# Calendar Year Month                       ...
# 2011          August        2.771524e+08  ...        7.246003e+08
#               December      5.409526e+08  ...        1.273327e+09
#
# [2 rows x 240 columns]

# %%
grouped_df.columns
# Out:
# Index(['Withholding mean', 'Withholding sum', 'Withholding median',
#        'Withholding amin', 'Withholding amax',
#        'Income Tax Estimates & Finals mean',
#        'Income Tax Estimates & Finals sum',
#        'Income Tax Estimates & Finals median',
#        'Income Tax Estimates & Finals amin',
#        'Income Tax Estimates & Finals amax',
#        ...
#        'Beverage Container Deposits mean', 'Beverage Container Deposits sum',
#        'Beverage Container Deposits median',
#        'Beverage Container Deposits amin', 'Beverage Container Deposits amax',
#        'Total Revenue mean', 'Total Revenue sum', 'Total Revenue median',
#        'Total Revenue amin', 'Total Revenue amax'],
#       dtype='object', length=240)

# %%
#groupby_calendar_df = conneticut_df.groupby('Calendar Year', as_index= False).agg([np.mean, np.sum, np.median,  np.min, np.max])
#groupby_calendar_df.head(3)
#https://towardsdatascience.com/functions-that-generate-a-multiindex-in-pandas-and-how-to-remove-the-levels-7aa15ac7ca95

# %%
#Grouped by Month(to visualize seasonality Trends)
grouped_monthly_df = conneticut_df.groupby( 'Month').agg([np.mean, np.sum, np.median,  np.min, np.max])
grouped_monthly_df.head(3)
# Out:
#          Calendar Year                 ... Total Revenue
#                   mean    sum  median  ...        median          amin          amax
# Month                                  ...
# April           2016.5  20165  2016.5  ...  2.524467e+09  1.417491e+09  3.083017e+09
# August          2015.5  20155  2015.5  ...  7.896562e+08  6.588891e+08  9.925937e+08
# December        2015.5  20155  2015.5  ...  1.549661e+09  1.273327e+09  1.843986e+09
#
# [3 rows x 245 columns]

# %%
grouped_monthly_df.columns = grouped_monthly_df.columns.map(' '.join)
grouped_monthly_df.head(2)
# Out:
#         Calendar Year mean  ...  Total Revenue amax
# Month                       ...
# April               2016.5  ...        3.083017e+09
# August              2015.5  ...        9.925937e+08
#
# [2 rows x 245 columns]

# %%
grouped_monthly_df = grouped_monthly_df.drop(['Calendar Year mean', 'Calendar Year sum', 'Calendar Year median', 'Calendar Year amax', 'Calendar Year amin'], axis = 1)
grouped_monthly_df.head(2)
# Out:
#         Withholding mean  ...  Total Revenue amax
# Month                     ...
# April       4.707595e+08  ...        3.083017e+09
# August      3.268116e+08  ...        9.925937e+08
#
# [2 rows x 240 columns]

# %% [markdown]
# Plotting:
# WE can graph breakdown of Total revenue mean, Total Revenue sum respectively by the mean and sum of each subcategory
# Steps:
# Need to filter out the dataframe to onely the columns we want(sum, mean) of each category.

# %%
conneticut_df.shape
# Out:
# (120, 51)

# %%
conneticut_df.tail(10)
# Out:
#          Month  Calendar Year  ... Beverage Container Deposits  Total Revenue
# 110  September           2020  ...                    23921.94   1.773954e+09
# 111    October           2020  ...                  8812493.26   1.574225e+09
# 112   November           2020  ...                  2190175.49   1.309999e+09
# 113   December           2020  ...                   672073.30   1.799617e+09
# 114    January           2021  ...                  6999553.31   2.176623e+09
# 115   February           2021  ...                  2892353.49   1.348489e+09
# 116      March           2021  ...                    26313.35   2.110485e+09
# 117      April           2021  ...                  9145564.99   2.390339e+09
# 118        May           2021  ...                   498546.16   2.154781e+09
# 119       June           2021  ...                 12240494.98   4.114055e+09
#
# [10 rows x 51 columns]

# %%
conneticut_df['Calendar Year'].min()
# Out:
# 2011

# %%
conneticut_df['Calendar Year'].max()
# Out:
# 2021

# %% [markdown]
# Metadata:
# *   Subcategorization: Breaks down Total Sales Tax Revenue in Columns of subcategories(Lots of 0s, N/A values within the rows of data)
# *   Date: 'Month', 'Calendar Year'(July 2011 to June 2021)
# *   Revenue: Multiple columns of subcategories of revenue
# *   Municipality: N/A

# %% [markdown]
# #Iowa

# %%
iowa_df = pd.read_csv('Iowa_Local_Option_Sales_Tax_Receipts_by_Month_and_Location.csv')
iowa_df.head(10)
# Out:
#    Co# Jurisdiction             Fiscal Year  ...  September    August      July
# 0   42      WHITTON  01/01/2007 12:00:00 AM  ...    1000.22   1000.22   1000.22
# 1   92   WASHINGTON  01/01/2005 12:00:00 AM  ...   40605.93  40605.91  40605.91
# 2   52       Oxford  01/01/2016 12:00:00 AM  ...       0.00      0.00      0.00
# 3   42        OWASA  01/01/2010 12:00:00 AM  ...     291.03    291.02    291.02
# 4   92   WASHINGTON  01/01/2009 12:00:00 AM  ...   52334.71  52334.70  52334.70
# 5   42        OWASA  01/01/2008 12:00:00 AM  ...     284.63    284.63    284.63
# 6   52       OXFORD  01/01/2006 12:00:00 AM  ...        NaN       NaN       NaN
# 7   33      FAYETTE  01/01/2010 12:00:00 AM  ...    7161.13   7161.11   7161.11
# 8   52        HILLS  01/01/2000 12:00:00 AM  ...        NaN       NaN       NaN
# 9   42        UNION  01/01/2011 12:00:00 AM  ...    3284.62   3284.62   3284.62
#
# [10 rows x 17 columns]

# %%
wash_jurisdiction_df = iowa_df[iowa_df['Jurisdiction'] == 'WASHINGTON']
wash_jurisdiction_df
# Out:
#      Co# Jurisdiction             Fiscal Year  ...  September    August      July
# 1     92   WASHINGTON  01/01/2005 12:00:00 AM  ...   40605.93  40605.91  40605.91
# 4     92   WASHINGTON  01/01/2009 12:00:00 AM  ...   52334.71  52334.70  52334.70
# 33    92   WASHINGTON  01/01/2011 12:00:00 AM  ...   58811.66  58811.66  58811.66
# 40    92   WASHINGTON  01/01/2004 12:00:00 AM  ...   31948.80  31948.80  31948.80
# 58    92   WASHINGTON  01/01/2002 12:00:00 AM  ...        NaN       NaN       NaN
# 73    92   WASHINGTON  01/01/2010 12:00:00 AM  ...   58389.97  58389.95  58389.95
# 82    92   WASHINGTON  01/01/2006 12:00:00 AM  ...   33795.35  33795.33  33795.33
# 83    92   WASHINGTON  01/01/2000 12:00:00 AM  ...        NaN       NaN       NaN
# 84    92   WASHINGTON  01/01/2003 12:00:00 AM  ...       0.00      0.00      0.00
# 85    92   WASHINGTON  01/01/2001 12:00:00 AM  ...        NaN       NaN       NaN
# ...

# %%
wash_jurisdiction_df['Fiscal Year'].unique()
# Out:
# array(['01/01/2005 12:00:00 AM', '01/01/2009 12:00:00 AM',
#        '01/01/2011 12:00:00 AM', '01/01/2004 12:00:00 AM',
#        '01/01/2002 12:00:00 AM', '01/01/2010 12:00:00 AM',
#        '01/01/2006 12:00:00 AM', '01/01/2000 12:00:00 AM',
#        '01/01/2003 12:00:00 AM', '01/01/2001 12:00:00 AM',
#        '01/01/2007 12:00:00 AM', '01/01/2008 12:00:00 AM',
#        '01/01/2013 12:00:00 AM', '01/01/2012 12:00:00 AM'], dtype=object)

# %%
iowa_df.shape
# Out:
# (19608, 17)

# %%
iowa_df['Fiscal Year'].unique()
# Out:
# array(['01/01/2007 12:00:00 AM', '01/01/2005 12:00:00 AM',
#        '01/01/2016 12:00:00 AM', '01/01/2010 12:00:00 AM',
#        '01/01/2009 12:00:00 AM', '01/01/2008 12:00:00 AM',
#        '01/01/2006 12:00:00 AM', '01/01/2000 12:00:00 AM',
#        '01/01/2011 12:00:00 AM', '01/01/2014 12:00:00 AM',
#        '01/01/2002 12:00:00 AM', '01/01/2004 12:00:00 AM',
#        '01/01/2001 12:00:00 AM', '01/01/2013 12:00:00 AM',
#        '01/01/2003 12:00:00 AM', '01/01/2015 12:00:00 AM',
#        '01/01/2012 12:00:00 AM', '01/01/2017 12:00:00 AM',
#        '01/01/2018 12:00:00 AM'], dtype=object)

# %% [markdown]
# Meta Data: Jurisdiction Fiscal Year(Can extract calendar date), value totql by month

# %% [markdown]
# We have monthly tax fevenue by year pe month but the structure o the data poses issues. each month is given its own column making it difficult to peform aggregation to be able to visualize trends and plots.
#
# Revenue: Broken down by month for each fiscal year
# Municipality: Broken down by 'Jurisdiction'
# Category: Not given category of Sales Tax Revenue
# State: Iowa

# %% [markdown]
# Metadata:
# *   Subcategorization: N/A
# *   Date: 'Month'(each month has its own column), 'Fiscal Year'(2001- 2018)
# *   Revenue: Contains breakdown of revenue by month for each fiscal year by jurisdiction
# *   Municipality: 'Jurisdiction' column

# %% [markdown]
# #Texas

# %%
texas_df = pd.read_csv('Texas_County_Returns.csv')
texas_df.head(10)
# Out:
#    Tax ID  Sub Tax  ... Unavailable  Report Period Type
# 0      63       10  ...       False           QUARTERLY
# 1      70       78  ...       False           QUARTERLY
# 2      63       10  ...       False           QUARTERLY
# 3      63       10  ...       False           QUARTERLY
# 4      63       10  ...       False           QUARTERLY
# 5      88       18  ...       False           QUARTERLY
# 6      88       18  ...       False           QUARTERLY
# 7      70       70  ...       False           QUARTERLY
# 8      20       80  ...       False           QUARTERLY
# 9      70       70  ...       False           QUARTERLY
#
# [10 rows x 11 columns]

# %%
texas_df.shape
# Out:
# (29719, 11)

# %%
texas_filtered_df = texas_df[texas_df['Total Due'] > 0]

# %%
texas_filtered_df.shape
# Out:
# (6561, 11)

# %%
texas_filtered_df
# Out:
#        Tax ID  Sub Tax  ... Unavailable  Report Period Type
# 4          63       10  ...       False           QUARTERLY
# 7          70       70  ...       False           QUARTERLY
# 9          70       70  ...       False           QUARTERLY
# 10         70       70  ...       False           QUARTERLY
# 15         70       70  ...       False           QUARTERLY
# ...       ...      ...  ...         ...                 ...
# 29702      63       10  ...       False           QUARTERLY
# 29703      70       70  ...       False           QUARTERLY
# 29707      70       70  ...       False           QUARTERLY
# 29714      63       10  ...       False           QUARTERLY
# 29715      63       10  ...       False           QUARTERLY
#
# [6561 rows x 11 columns]

# %%
texas_filtered_df.sort_values('Year', ascending= True)
# Out:
#        Tax ID  Sub Tax  ... Unavailable  Report Period Type
# 13478      88       18  ...       False           QUARTERLY
# 14112      70       70  ...       False           QUARTERLY
# 14106      70       70  ...       False           QUARTERLY
# 9338       70       70  ...       False           QUARTERLY
# 14101      70       70  ...       False           QUARTERLY
# ...       ...      ...  ...         ...                 ...
# 5244       70       70  ...       False           QUARTERLY
# 22182      70       70  ...       False           QUARTERLY
# 23454      70       70  ...       False           QUARTERLY
# 17519      63       10  ...       False           QUARTERLY
# 23922      70       70  ...       False           QUARTERLY
#
# [6561 rows x 11 columns]

# %%
texas_filtered_df['Tax Description'].unique()
# Out:
# array(['MIXED BEVERAGE SALES TAX',
#        'SELLER FINANCED SALES - MOTOR VEHICLE SALES TAX',
#        'CIGARS AND TOBACCO PRODUCTS TAX - DISTRIBUTORS',
#        'SELLER FINANCED SALES - MV SALES TAX SURCHARGE',
#        'OYSTER SALES FEE'], dtype=object)

# %%
texas_filtered_df['Year'].min()
# Out:
# 2011

# %%
texas_filtered_df['Year'].max()
# Out:
# 2016

# %%
texas_filtered_df['Unavailable'].unique()
# Out:
# array([False])

# %%
texas_filtered_df['Report Period Type'].unique()
# Out:
# array(['QUARTERLY'], dtype=object)

# %% [markdown]
# We only have 6,000 rows left after filtering the data for values that were greater than 0.
#
# What do negative total due values mean?
#
# What does the Taxpayers Column mean?

# %% [markdown]
# Metadata:
# *   Subcategorization: Tax Description
# *   Date: Year, Quarter (2011 - 2016)
# *   Revenue: 'Total Due'
# *   Municipality: 'County Name' column

# %% [markdown]
# #Parish(2)

# %%
parish_df = pd.read_csv('Budgeted_RevenuesParish_LA.csv')
parish_df.head(10)
# Out:
#        UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0   2018-5-2189       2189  ...          -313846.78      False
# 1   2019-4-2189       2189  ...          -341073.56      False
# 2   2019-3-2189       2189  ...          -336890.84      False
# 3  2019-10-2189       2189  ...          -336890.84      False
# 4   2020-4-2189       2189  ...          -316896.30      False
# 5  2018-11-2189       2189  ...          -122846.78      False
# 6   2021-6-2189       2189  ...          -332314.27      False
# 7   2018-6-2189       2189  ...          -313846.78      False
# 8   2020-2-2189       2189  ...          -316896.30      False
# 9   2020-9-2189       2189  ...          -316896.30      False
#
# [10 rows x 47 columns]

# %%
parish_df['Object'].unique()
# Out:
# array(['AD VALOREM TAXES', 'SALES TAX', 'BEER TAXES', 'FRANCHISE FEES',
#        'PARCEL FEES', 'AD VALOREM TAXES - JUV. DET.', 'AD VALOREM 5 YEAR',
#        'ALCOHOLIC LICENSES & PERMITS', 'OCCUPATIONAL LICENSES',
#        'MOBILE HOME LICENSES', 'BUILDING PERMITS', 'PLANNING FEES',
#        'ZONING FEES', 'MISCELLANEOUS REVENUES', 'STATE REVENUE SHARING',
#        'STATE REVENUE SHARING-5 YEAR', 'STATE SHARED SEVERANCE',
#        'PARISH TRANSPORTATION FUND', 'CIVIL DEFENSE - E.M.A.',
#        'FIRE INSURANCE REBATE-ST TREA', 'U.S. TREASURY - HUD',
#        'REIMBURSEMENT - FEMA', 'HUD - SPECIAL REVENUE',
#        'REIMB. - WIC PROGRAM', 'STATE SHARE LIC BD FEE',
#        'ADMINISTRATIVE FEES- 4%', 'MISC REV REIMB SAL/BEN',
#        'RENTALS FEES', 'GRANT ADMINISTRATION FEES', 'COURT FINES',
#        'BOND FORFEITURES', 'PROCEEDS - DRUG SEIZED PROP.', 'SERVICE FEES',
#        'SEWER DEVELOP FEES', 'MISCELLANEOUS INSURANCE REFUND',
# ...

# %%
parish_df['FiscalYear'].unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022])

# %%
parish_df['FiscalMonth'].unique()
# Out:
# array(['05/01/2018 12:00:00 AM', '04/01/2019 12:00:00 AM',
#        '03/01/2019 12:00:00 AM', '10/01/2019 12:00:00 AM',
#        '04/01/2020 12:00:00 AM', '11/01/2018 12:00:00 AM',
#        '06/01/2021 12:00:00 AM', '06/01/2018 12:00:00 AM',
#        '02/01/2020 12:00:00 AM', '09/01/2020 12:00:00 AM',
#        '08/01/2019 12:00:00 AM', '01/01/2021 12:00:00 AM',
#        '01/01/2018 12:00:00 AM', '11/01/2021 12:00:00 AM',
#        '09/01/2021 12:00:00 AM', '07/01/2019 12:00:00 AM',
#        '12/01/2020 12:00:00 AM', '02/01/2021 12:00:00 AM',
#        '10/01/2018 12:00:00 AM', '05/01/2020 12:00:00 AM',
#        '03/01/2018 12:00:00 AM', '05/01/2019 12:00:00 AM',
#        '12/01/2019 12:00:00 AM', '04/01/2021 12:00:00 AM',
#        '08/01/2018 12:00:00 AM', '07/01/2020 12:00:00 AM',
#        '03/01/2021 12:00:00 AM', '06/01/2020 12:00:00 AM',
#        '09/01/2018 12:00:00 AM', '08/01/2021 12:00:00 AM',
#        '11/01/2020 12:00:00 AM', '06/01/2019 12:00:00 AM',
# ...

# %% [markdown]
# Metadata:
# *   Subcategorization: Object, Fund, AccountDescription
# *   Date: Year, Month (2018 - 2022)(May 2018 to May 2022)
# *   Revenue: 'ObligatedAmount'
# *   Municipality: N/A

# %% [markdown]
# #Tennessee Dataset, 11 on datacataloguing

# %%
tennsee_df = pd.read_csv('Tennesee_statesalestaxcollection.csv')
tennsee_df.head(10)
# Out:
#      County        Date       Value LastReportedDate  Unnamed: 4
# 0  Anderson  2020-11-30  8974607.43       2021-02-01         NaN
# 1  Anderson  2020-12-31  6555367.01       2021-02-01         NaN
# 2  Anderson  2018-05-31  7234151.99       2018-10-17         NaN
# 3  Anderson  2017-10-31  7006165.71       2018-04-16         NaN
# 4  Anderson  2017-11-30  6817796.08       2018-04-16         NaN
# 5  Anderson  2017-12-31  7361363.45       2018-04-16         NaN
# 6  Anderson  2017-07-31  6726978.96       2018-04-16         NaN
# 7  Anderson  2017-08-31  6734805.46       2018-04-16         NaN
# 8  Anderson  2017-09-30  6877220.57       2018-04-16         NaN
# 9  Anderson  2018-01-31  7470786.73       2018-04-16         NaN

# %%
tennsee_df.tail(10)
# Out:
#       County        Date        Value LastReportedDate  Unnamed: 4
# 4617  Wilson  2018-03-31  10460755.28       2018-06-25         NaN
# 4618  Wilson  2018-02-28   9909734.80       2018-04-16         NaN
# 4619  Wilson  2018-04-30  13087357.81       2018-05-22         NaN
# 4620  Wilson  2018-07-31  13719316.97       2021-02-01         NaN
# 4621  Wilson  2018-08-31  12978998.01       2021-02-01         NaN
# 4622  Wilson  2018-09-30  12764210.50       2021-02-01         NaN
# 4623  Wilson  2018-11-30  12263586.01       2021-02-01         NaN
# 4624  Wilson  2018-10-31  12505212.56       2021-02-01         NaN
# 4625  Wilson  2018-12-31  12366479.64       2021-02-01         NaN
# 4626                NaN          NaN              NaN         NaN

# %%
tennsee_df['Date'] = tennsee_df['Date'].astype('datetime64')

# %%
tennsee_df.dtypes
# Out:
# County                      object
# Date                datetime64[ns]
# Value                      float64
# LastReportedDate            object
# Unnamed: 4                 float64
# dtype: object

# %%
tennsee_df['year'] = tennsee_df['Date'].dt.year
tennsee_df['month'] = tennsee_df['Date'].dt.month

# %%
tennsee_df.head(5)
# Out:
#      County       Date       Value LastReportedDate  Unnamed: 4    year  month
# 0  Anderson 2020-11-30  8974607.43       2021-02-01         NaN  2020.0   11.0
# 1  Anderson 2020-12-31  6555367.01       2021-02-01         NaN  2020.0   12.0
# 2  Anderson 2018-05-31  7234151.99       2018-10-17         NaN  2018.0    5.0
# 3  Anderson 2017-10-31  7006165.71       2018-04-16         NaN  2017.0   10.0
# 4  Anderson 2017-11-30  6817796.08       2018-04-16         NaN  2017.0   11.0

# %%
#see which counties have the highest total values
total_by_county = tennsee_df.groupby('County', as_index = False)['Value'].sum()
total_by_county.head(10)
# Out:
#      County         Value
# 0           0.000000e+00
# 1  Anderson  3.138607e+08
# 2   Bedford  1.392363e+08
# 3    Benton  3.799779e+07
# 4   Bledsoe  9.061945e+06
# 5    Blount  4.990196e+08
# 6   Bradley  3.541067e+08
# 7  Campbell  9.400686e+07
# 8    Cannon  1.757439e+07
# 9   Carroll  4.846346e+07

# %%
total_by_county.sort_values('Value', ascending = False).head(10)
#we can see that Davidson, Shelby, Knox are the counties with highest total revenue.
# Out:
#                             Value
# County
# Total (YTD FY 2021)  2.674054e+12
# Subtotal             2.421046e+10
# Out of State         5.914132e+09
# Davidson             4.441812e+09
# Shelby               3.464201e+09
# Knox                 2.332915e+09
# Hamilton             1.619608e+09
# Rutherford           1.339320e+09
# Williamson           1.303801e+09
# Sevier               9.711945e+08

# %%
total_by_county.values

# %% [markdown]
# Lets explore Davidson, Shelby, KNox, Hamilton, and Rutherford, as they have the highest total value

# %%
top_counties = tennsee_df.loc[tennsee_df['County'].isin(['Davidson', 'Shelby', 'Hamilton', 'Knox', 'Rutherford'])]

top_counties.head(3)
# Out:
#        County       Date         Value  ... Unnamed: 4    year  month
# 738  Davidson 2020-11-30  1.027306e+08  ...        NaN  2020.0   11.0
# 739  Davidson 2020-12-31  9.680746e+07  ...        NaN  2020.0   12.0
# 740  Davidson 2018-05-31  1.082558e+08  ...        NaN  2018.0    5.0
#
# [3 rows x 7 columns]

# %%
total_by_county = top_counties.groupby(['County', 'Date'], as_index = False)['Value'].sum()
total_by_county.head(10)
# Out:
#      County       Date         Value
# 0  Davidson 2017-07-31  1.052987e+08
# 1  Davidson 2017-08-31  1.046664e+08
# 2  Davidson 2017-09-30  1.069310e+08
# 3  Davidson 2017-10-31  1.056981e+08
# 4  Davidson 2017-11-30  1.090318e+08
# 5  Davidson 2017-12-31  1.025732e+08
# 6  Davidson 2018-01-31  1.168252e+08
# 7  Davidson 2018-02-28  9.042348e+07
# 8  Davidson 2018-03-31  9.722921e+07
# 9  Davidson 2018-04-30  1.151239e+08

# %%
total_by_county['Year'] = total_by_county['Date'].astype(str).str[:4]
total_by_county['Month'] = total_by_county['Date'].astype(str).str[5:7]
total_by_county['Year-Month'] = total_by_county['Year'] + '-' + total_by_county['Month']

total_by_county.head(2)
# Out:
#      County       Date         Value  Year Month Year-Month
# 0  Davidson 2017-07-31  1.052987e+08  2017    07    2017-07
# 1  Davidson 2017-08-31  1.046664e+08  2017    08    2017-08

# %%
total_by_county.tail(2)
# Out:
#      County       Date        Value  Year Month Year-Month
# 203  Shelby 2020-11-30  84147424.48  2020    11    2020-11
# 204  Shelby 2020-12-31  81994517.43  2020    12    2020-12

# %% [markdown]
# Figure out how to add 'hue' with plotly express

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=total_by_county['Year-Month'].astype(dtype=str), 
                        y=total_by_county['Value'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Pineallas County',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6e4c63fd-c7ac-4779-8686-5e6b10fdc4db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e4c63fd-c7ac-4779-8686-5e6b10fdc4db")) {
#                     Plotly.newPlot(
#                         '6e4c63fd-c7ac-4779-8686-5e6b10fdc4db',
# ...

# %%
import seaborn as sns 

sns.lineplot(data = total_by_county["Value"])

# %%
sns.boxplot(x = 'Year-Month', y='Value', data = total_by_county)

# %%
# plotting wideform data
sns.lineplot(x="Year-Month", y="Value", data = total_by_county, hue="County", palette="Dark2")

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Value", data = total_by_county)

# %%
import plotly.express as px
fig = px.bar(total_by_county, x="Year-Month", y="Value", color="County")
fig.update_layout(title_text='Salex Tax REvenue in TN broken down by top 5 Counties', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f8fdc40-e670-4261-a720-45ec467d1ac4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f8fdc40-e670-4261-a720-45ec467d1ac4")) {
#                     Plotly.newPlot(
#                         '1f8fdc40-e670-4261-a720-45ec467d1ac4',
# ...

# %%
#filtering just so that we have those top 5 values
tennsee_df

# %%
#getting a monthly total of 
agg_tenn_df = tennsee_df.groupby(['year', 'month', 'County'], as_index = False)['Value'].sum()
agg_tenn_df.head(20)
# Out:
#       year  month      County         Value
# 0   2017.0    7.0    Anderson  6.726979e+06
# 1   2017.0    7.0     Bedford  3.208290e+06
# 2   2017.0    7.0      Benton  9.207480e+05
# 3   2017.0    7.0     Bledsoe  2.094306e+05
# 4   2017.0    7.0      Blount  1.225955e+07
# 5   2017.0    7.0     Bradley  8.779028e+06
# 6   2017.0    7.0    Campbell  2.506070e+06
# 7   2017.0    7.0      Cannon  4.724592e+05
# 8   2017.0    7.0     Carroll  1.135934e+06
# 9   2017.0    7.0      Carter  2.599841e+06
# 10  2017.0    7.0    Cheatham  1.789501e+06
# 11  2017.0    7.0     Chester  6.093631e+05
# 12  2017.0    7.0   Claiborne  1.165677e+06
# 13  2017.0    7.0        Clay  3.052851e+05
# 14  2017.0    7.0       Cocke  2.183514e+06
# 15  2017.0    7.0      Coffee  7.661490e+06
# 16  2017.0    7.0    Crockett  4.082945e+05
# 17  2017.0    7.0  Cumberland  4.623418e+06
# 18  2017.0    7.0    Davidson  1.052987e+08
# 19  2017.0    7.0      DeKalb  1.099305e+06

# %%
agg_tenn_df.tail(20)
# Out:
#                                County
# year   month County
# 2020.0 12.0  Sequatchie  8.474824e+05
#              Sevier      3.016846e+07
#              Shelby      8.199452e+07
#              Smith       1.022666e+06
#              Stewart     5.615871e+05
#              Subtotal    8.536396e+08
#              Sullivan    1.485821e+07
#              Sumner      1.392785e+07
#              Tipton      2.548628e+06
#              Trousdale   2.856064e+05
#              Unicoi      9.160296e+05
#              Union       5.300419e+05
#              VanBuren    1.244725e+05
#              Warren      2.498078e+06
#              Washington  1.393797e+07
#              Wayne       5.027013e+05
#              Weakley     1.802168e+06
#              White       1.456418e+06
#              Williamson  3.380554e+07
#              Wilson      1.366472e+07

# %%
And_df['Date'].unique()
# Out:
# array(['2020-11-30', '2020-12-31', '2018-05-31', '2017-10-31',
#        '2017-11-30', '2017-12-31', '2017-07-31', '2017-08-31',
#        '2017-09-30', '2018-01-31', '2018-02-28', '2018-03-31',
#        '2018-04-30', '2018-07-31', '2018-08-31', '2018-09-30',
#        '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31',
#        '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31',
#        '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
#        '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#        '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#        '2020-06-30', '2020-07-31', '2020-08-31', '2020-09-30',
#        '2020-10-31'], dtype=object)

# %%
tennsee_df.shape
# Out:
# (4627, 5)

# %%
tennsee_df['Date'].unique()
# Out:
# array(['2020-11-30', '2020-12-31', '2018-05-31', '2017-10-31',
#        '2017-11-30', '2017-12-31', '2017-07-31', '2017-08-31',
#        '2017-09-30', '2018-01-31', '2018-02-28', '2018-03-31',
#        '2018-04-30', '2018-07-31', '2018-08-31', '2018-09-30',
#        '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31',
#        '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31',
#        '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
#        '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#        '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#        '2020-06-30', '2020-07-31', '2020-08-31', '2020-09-30',
#        '2020-10-31', nan], dtype=object)

# %%
tennsee_df['County'].unique()
# Out:
# array(['Anderson', 'Bedford', 'Benton', 'Bledsoe', 'Blount', 'Bradley',
#        'Campbell', 'Cannon', 'Carroll', 'Carter', 'Cheatham', 'Chester',
#        'Claiborne', 'Clay', 'Cocke', 'Coffee', 'Crockett', 'Cumberland',
#        'Davidson', 'Decatur', 'DeKalb', 'Dickson', 'Dyer', 'Fayette',
#        'Fentress', 'Franklin', 'Gibson', 'Giles', 'Grainger', 'Greene',
#        'Grundy', 'Hamblen', 'Hamilton', 'Hancock', 'Hardeman', 'Hardin',
#        'Hawkins', 'Haywood', 'Henderson', 'Henry', 'Hickman', 'Houston',
#        'Humphreys', 'Jackson', 'Jefferson', 'Johnson', 'Knox', 'Lake',
#        'Lauderdale', 'Lawrence', 'Lewis', 'Lincoln', 'Loudon', 'Macon',
#        'Madison', 'Marion', 'Marshall', 'Maury', 'McMinn', 'McNairy',
#        'Mcnairy', 'Meigs', 'Monroe', 'Montgomery', 'Moore', 'Morgan',
#        'Obion', 'OUT OF STATE', 'Out Of State', 'Out of State', 'Overton',
#        'Perry', 'Pickett', 'Polk', 'Putnam', 'Rhea', 'Roane', 'Robertson',
# ...

# %% [markdown]
# Metadata:
# *   Subcategorization: N/A
# *   Date: Column of Calendar Date(2017 - 2020)(May 2017 - August 2020)
# *   Revenue: 'Value'
# *   Municipality: 'County'

# %% [markdown]
# #St. Louis, Missouri

# %%
st_louis_df = pd.read_csv('StLouis_Federal_reserve_SalesTax.csv')
st_louis_df.head(10)
# Out:
#          DATE  QTAXTOTALQTAXCAT3GANO
# 0  1994-01-01                   2289
# 1  1994-04-01                   2304
# 2  1994-07-01                   2169
# 3  1994-10-01                   2328
# 4  1995-01-01                   2469
# 5  1995-04-01                   2511
# 6  1995-07-01                   2316
# 7  1995-10-01                   2457
# 8  1996-01-01                   2615
# 9  1996-04-01                   2817

# %%
st_louis_df.shape
# Out:
# (109, 2)

# %%
st_louis_df.dtypes
# Out:
# DATE                     object
# QTAXTOTALQTAXCAT3GANO     int64
# dtype: object

# %%
st_louis_df['DATE'].unique()
# Out:
# array(['1994-01-01', '1994-04-01', '1994-07-01', '1994-10-01',
#        '1995-01-01', '1995-04-01', '1995-07-01', '1995-10-01',
#        '1996-01-01', '1996-04-01', '1996-07-01', '1996-10-01',
#        '1997-01-01', '1997-04-01', '1997-07-01', '1997-10-01',
#        '1998-01-01', '1998-04-01', '1998-07-01', '1998-10-01',
#        '1999-01-01', '1999-04-01', '1999-07-01', '1999-10-01',
#        '2000-01-01', '2000-04-01', '2000-07-01', '2000-10-01',
#        '2001-01-01', '2001-04-01', '2001-07-01', '2001-10-01',
#        '2002-01-01', '2002-04-01', '2002-07-01', '2002-10-01',
#        '2003-01-01', '2003-04-01', '2003-07-01', '2003-10-01',
#        '2004-01-01', '2004-04-01', '2004-07-01', '2004-10-01',
#        '2005-01-01', '2005-04-01', '2005-07-01', '2005-10-01',
#        '2006-01-01', '2006-04-01', '2006-07-01', '2006-10-01',
#        '2007-01-01', '2007-04-01', '2007-07-01', '2007-10-01',
#        '2008-01-01', '2008-04-01', '2008-07-01', '2008-10-01',
# ...

# %% [markdown]
# Metadata:
# *   Subcategorization: N/A
# *   Date: Quarterly data fron 1994 to 2021
# *   Revenue: 'Value'
# *   Municipality: N/A

# %% [markdown]
# #Tennesee Collection Summaries 2021, August

# %%
tenn_df_coll_df = pd.read_excel(r'Tennessee_collection_summaries.xlsx', engine='openpyxl')
tenn_df_coll_df.head(10)
# Out:
#                                              ... Unnamed: 19
# 0                                       NaN  ...         NaN
# 1                                       NaN  ...         NaN
# 2                                       NaN  ...         NaN
# 3                                       NaN  ...         NaN
# 4                                       NaN  ...         NaN
# 5                                            ...         NaN
# 6                                            ...         NaN
# 7                       2021-10-01 00:00:00  ...         NaN
# 8                              CLASS OF TAX  ...         NaN
# 9                             Sales and Use  ...         NaN
#
# [10 rows x 20 columns]

# %% [markdown]
# Data is read in weird, not sure if it is an issue with the formatting. Try to convert into csv file and look into it again in the future

# %% [markdown]
# #Kansas Dataset

# %%
kansas_df = pd.read_excel(r'Kansas_Revenue_monthly_11_21.xlsx', engine='openpyxl')
kansas_df
# Out:
#          County/City  Tax Rate  ... Unnamed: 10  Unnamed: 11
# 0       Allen County    0.0125  ...         NaN          NaN
# 1    Anderson County    0.0150  ...         NaN          NaN
# 2    Atchison County    0.0125  ...         NaN          NaN
# 3      Barber County    0.0100  ...         NaN          NaN
# 4      Barton County    0.0100  ...         NaN          NaN
# ..               ...       ...  ...         ...          ...
# 423              NaN       NaN  ...         NaN          NaN
# 424              NaN       NaN  ...         NaN          NaN
# 425              NaN       NaN  ...         NaN          NaN
# 426              NaN       NaN  ...         NaN          NaN
# 427              NaN       NaN  ...         NaN          NaN
#
# [428 rows x 12 columns]

# %%
kansas_df.tail(20)
# Out:
#                      County/City  Tax Rate  ... Unnamed: 10  Unnamed: 11
# 408                    Statewide       NaN  ...         NaN          NaN
# 409                          NaN       NaN  ...         NaN          NaN
# 410  Washburn U. (in Shawnee Co)       NaN  ...         NaN          NaN
# 411                          NaN       NaN  ...         NaN          NaN
# 412                          NaN       NaN  ...         NaN          NaN
# 413                          NaN       NaN  ...         NaN          NaN
# 414                          NaN       NaN  ...         NaN          NaN
# 415                          NaN       NaN  ...         NaN          NaN
# 416                          NaN       NaN  ...         NaN          NaN
# 417                          NaN       NaN  ...         NaN          NaN
# 418                          NaN       NaN  ...         NaN          NaN
# 419                          NaN       NaN  ...         NaN          NaN
# ...

# %% [markdown]
# Metadata:
# Granularity: Monthly data from january 2020 to November 2021.
# Effective Data(of tax rate)
# Tax Rate
# Percent Change

# %% [markdown]
# Issues/potential problems:
# Each month has its own dataframe, need to reformat the dataframes and combine monthy dataframes so that it would be useful for us. Not sure if this is possible for us to do.
# Gives a lot of null values when reading in the data for some reason

# %% [markdown]
# Metadata:
# *   Subcategorization: N/A
# *   Date: Quarterly data fron 1994 to 2021
# *   Revenue: 'Value'
# *   Municipality: N/A

# %% [markdown]
# #Georgia Quarterly

# %%
georgia_df = pd.read_csv('Georgia_Quarterly_Sales.csv')
georgia_df.head(10)
# Out:
#          DATE  QTAXTOTALQTAXCAT3GANO
# 0  1994-01-01                   2289
# 1  1994-04-01                   2304
# 2  1994-07-01                   2169
# 3  1994-10-01                   2328
# 4  1995-01-01                   2469
# 5  1995-04-01                   2511
# 6  1995-07-01                   2316
# 7  1995-10-01                   2457
# 8  1996-01-01                   2615
# 9  1996-04-01                   2817

# %%
georgia_df.tail(10)
# Out:
#            DATE  QTAXTOTALQTAXCAT3GANO
# 99   2018-10-01                   6003
# 100  2019-01-01                   5318
# 101  2019-04-01                   6735
# 102  2019-07-01                   5916
# 103  2019-10-01                   6029
# 104  2020-01-01                   5651
# 105  2020-04-01                   5351
# 106  2020-07-01                   7263
# 107  2020-10-01                   6377
# 108  2021-01-01                   6480

# %% [markdown]
# Gives us quarterly data from 1994 to 2021 january
# Metadata: only date and values

# %% [markdown]
# Metadata:
# *   Subcategorization: N/A
# *   Date: Quarterly data fron 1994 to 2021
# *   Revenue: 'Value'
# *   Municipality: N/A

# %% [markdown]
# #Commonwealth, Virgina

# %%
Commonwealth_virgina_df = pd.read_csv('Commonwealth_Virginia_Revenue_Collections.csv')
Commonwealth_virgina_df.head(10)
# Out:
#    Fiscal Year  ...                 Revenue Source/Revenue Source Name
# 0         2017  ...                MassDOT 2010A-2 Debt Service (2154)
# 1         2018  ...                SUPPORTED EMPLOYMENT PROGRAM (1716)
# 2         2016  ...                         TRUST CONTRIBUTIONS (7200)
# 3         2009  ...                RAPE PREVENTION AND EDUCATIO (1421)
# 4         2018  ...                               MISCELLANEOUS (7199)
# 5         2011  ...                   FUNDS RETURNED BY TRUSTEE (9036)
# 6         2018  ...                  FEES-OUT OF STATE BAKERIES (0606)
# 7         2017  ...  Substance Abuse Prevention/Treatment-Block Gra...
# 8         2019  ...                                    INTEREST (2100)
# 9         2009  ...                                      ESTATE (0117)
#
# [10 rows x 21 columns]

# %%
Commonwealth_virgina_df.shape
# Out:
# (94443, 21)

# %%
Commonwealth_virgina_df['Fiscal Year'].min()
# Out:
# 2008

# %%
Commonwealth_virgina_df['Fiscal Year'].max()
# Out:
# 2022

# %%
Commonwealth_virgina_df[Commonwealth_virgina_df['Fiscal Year'] == 2022]
# Out:
#         Fiscal Year  ...                 Revenue Source/Revenue Source Name
# 257            2022  ...                                   DONATIONS (2044)
# 757            2022  ...                               SALES NON-TAX (7111)
# 976            2022  ...                         Local Options Meals (0258)
# 1132           2022  ...       WILSON FISH TANF COORDINATION PROGRAM (FD08)
# 1241           2022  ...                FED OPERAT REIMB-MED TLE XIX (5202)
# ...             ...  ...                                                ...
# 405632         2022  ...  Localized Efforts to Reduce Environmental Expo...
# 405633         2022  ...                             OTHER TRANSFERS (7188)
# 405634         2022  ...                                        FEES (0500)
# 405635         2022  ...               FARMERS MARKET COUPON PROGRAM (1807)
# 405636         2022  ...                           Mass Bays Estuary (1894)
#
# [7971 rows x 21 columns]

# %% [markdown]
# #EffingHam, IL (ERP)

# %%
#Budgeted_Revenues _Effingham_IL.csv
import pandas as pd
effingham_il_df = pd.read_csv('Budgeted_Revenues _Effingham_IL.csv')
effingham_il_df.head()
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance MultiYear
# 0  2018-1-1001       1001  ...             12000.0     False
# 1  2018-1-1013       1013  ...             85000.0     False
# 2  2018-1-1017       1017  ...              1000.0     False
# 3  2018-1-1032       1032  ...              1000.0     False
# 4  2018-1-1040       1040  ...              4060.0     False
#
# [5 rows x 47 columns]

# %%
effingham_il_df.shape
# Out:
# (2883, 47)

# %%
filtered_eff = effingham_il_df[effingham_il_df['Actual'] >0]
filtered_eff.shape
# Out:
# (2323, 47)

# %%
effingham_il_df.shape[0] - filtered_eff.shape[0]
#we have 560 rows where values in the actual column are not greater than 0. (<=0)
# Out:
# 560

# %%
effingham_il_df['Segment2'].unique()
# Out:
# array(['Administration', 'Police', 'Tourism', 'Public Properties',
#        'Human Resources', 'Economic Development', 'Water Treatment Plant',
#        'Utility Billing', 'Undefined', 'Street/Sewer Maintenance',
#        'Public Works', 'Technology/Communications', 'Telecommunications',
#        'Fire', 'Buildings', 'Waste Water Treatment Plant', 'City Clerks',
#        'Emergency Managment Agency', 'Water Maintenance'], dtype=object)

# %%
effingham_il_df['AccountDescription'].unique()
# Out:
# array(['Lease Agreements', 'Sale of Real Property',
#        'Sale of Personal Property', 'Sale of Police Vehicle',
#        'Advertisement', 'Donations', 'Opening of Graves',
#        'Sale of Cemetery Plots', 'Work Comp Loss Claim Reimburse',
#        'Health Insurance Withholding', 'Employee Contributions',
#        'Cafeteria Plan Adjustments', 'Business District Reimbursemen',
#        'Misc Revenue', 'Enterprise Fund', 'Evidence',
#        'EOY Acct Bal Carryover', 'Maintenance Garage',
#        'Obsolete - Revenue', 'Grants', 'Transfer From Other Funds',
#        'Interest', 'Property Tax', 'PPRT', 'State Allotments',
#        'State Auto Rental Tax', 'State Charitable Games',
#        'State Income Tax (LGDF)', 'State Sales Tax',
#        'State Street Light Reimburseme', 'State Street Sweeping Reimburs',
#        'State Light Repairs Reimbursem', 'State Use Tax',
#        'State Video Gaming Tax', 'Business District Tax', 'Utility Tax',
# ...

# %%
effingham_il_df.columns
# Out:
# Index(['UniqueId', 'AccountId', 'Entity', 'CharacterCode',
#        'CharacterCodeDescription', 'ObjectCode', 'Object', 'OrganizationCode',
#        'Organization', 'ProjectCode', 'Project', 'FullAccount', 'FundCode',
#        'Fund', 'Segment2Code', 'Segment2', 'Segment3Code', 'Segment3',
#        'Segment4Code', 'Segment4', 'Segment5Code', 'Segment5', 'Segment6Code',
#        'Segment6', 'Segment7Code', 'Segment7', 'Segment8Code', 'Segment8',
#        'AccountDescription', 'AccountType', 'AccountStatus', 'FiscalYear',
#        'FiscalMonth', 'OriginalBudget', 'RevisedBudget', 'Actual',
#        'Department', 'DepartmentGroup', 'FunctionDescription', 'FunctionGroup',
#        'FundGroup', 'LTDOriginalBudget', 'LTDRevisedBudget', 'Encumbrance',
#        'ObligatedAmount', 'UnencumberedBalance', 'MultiYear'],
#       dtype='object')

# %%
effingham_il_df.sort_values('FiscalYear', ascending= False)
# Out:
#           UniqueId  AccountId  ... UnencumberedBalance MultiYear
# 2882    2022-8-997        997  ...           -11496.63     False
# 2518    2022-2-938        938  ...             -518.43     False
# 2524    2022-2-944        944  ...             -217.37     False
# 2523    2022-2-943        943  ...              -82.59     False
# 2522    2022-2-942        942  ...              -32.72     False
# ...            ...        ...  ...                 ...       ...
# 147   2018-12-2730       2730  ...         -1240000.00     False
# 146   2018-12-2729       2729  ...          -166431.00     False
# 145   2018-12-2709       2709  ...         -1771147.00     False
# 144   2018-12-2708       2708  ...          -251323.00     False
# 0      2018-1-1001       1001  ...            12000.00     False
#
# [2883 rows x 47 columns]

# %%
effingham_il_df['FiscalMonth'].unique()
# Out:
# array(['05/01/2017 12:00:00 AM', '04/01/2018 12:00:00 AM',
#        '05/01/2018 12:00:00 AM', '04/01/2019 12:00:00 AM',
#        '05/01/2019 12:00:00 AM', '02/01/2020 12:00:00 AM',
#        '03/01/2020 12:00:00 AM', '04/01/2020 12:00:00 AM',
#        '06/01/2019 12:00:00 AM', '07/01/2019 12:00:00 AM',
#        '08/01/2019 12:00:00 AM', '09/01/2019 12:00:00 AM',
#        '10/01/2019 12:00:00 AM', '11/01/2019 12:00:00 AM',
#        '12/01/2019 12:00:00 AM', '01/01/2020 12:00:00 AM',
#        '05/01/2020 12:00:00 AM', '02/01/2021 12:00:00 AM',
#        '03/01/2021 12:00:00 AM', '04/01/2021 12:00:00 AM',
#        '06/01/2020 12:00:00 AM', '07/01/2020 12:00:00 AM',
#        '08/01/2020 12:00:00 AM', '09/01/2020 12:00:00 AM',
#        '10/01/2020 12:00:00 AM', '11/01/2020 12:00:00 AM',
#        '12/01/2020 12:00:00 AM', '01/01/2021 12:00:00 AM',
#        '05/01/2021 12:00:00 AM', '02/01/2022 12:00:00 AM',
#        '06/01/2021 12:00:00 AM', '07/01/2021 12:00:00 AM',
# ...

# %%
effingham_il_df['FiscalYear'].unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022])

# %%
effingham_il_df['Organization'].unique()
# Out:
# array(['Hotel Motel Admin', 'GF Admin', 'Water Admin', 'GF Police',
#        'Hotel Motel Tourism', 'Library Fund Admin',
#        'GF Public Properties', 'GF Human Resources',
#        'Library Fund Human Resoures', 'Water Human Resources',
#        'Sewer Human Resources', 'Hotel Motel Human Resources',
#        'Police Pension Human Resources', 'Fire Pension Human Resources',
#        'GF Econ Development', 'Water WTP', 'Sewer Utility Billing',
#        'Police Pension Admin', 'Fire Pension Admin', 'Sewer Admin',
#        'Ford Ave BD Admin', 'Northwest BD Admin', 'Triangle BD Admin',
#        'MFT Admin', 'Bond Proceeds Admin', 'TIF Main Admin',
#        'Capital Projects Admin', 'GF Public Prop Maint', 'OBSOLETE',
#        'TIF 1 Main Fund', 'General Fund', 'Water Fund',
#        'Capital Projects Fund', 'TIF Central Admin',
#        'TIF Outer Belt West Admin', 'TIF SC Industrial Admin',
#        'GF ST/SW Maintenance', 'GF Public Works',
# ...

# %%
effingham_il_df[effingham_il_df['Actual'] >0].shape
# Out:
# (2323, 47)

# %%
effingham_il_df.shape
# Out:
# (2883, 47)

# %%
effingham_il_df.columns
# Out:
# Index(['UniqueId', 'AccountId', 'Entity', 'CharacterCode',
#        'CharacterCodeDescription', 'ObjectCode', 'Object', 'OrganizationCode',
#        'Organization', 'ProjectCode', 'Project', 'FullAccount', 'FundCode',
#        'Fund', 'Segment2Code', 'Segment2', 'Segment3Code', 'Segment3',
#        'Segment4Code', 'Segment4', 'Segment5Code', 'Segment5', 'Segment6Code',
#        'Segment6', 'Segment7Code', 'Segment7', 'Segment8Code', 'Segment8',
#        'AccountDescription', 'AccountType', 'AccountStatus', 'FiscalYear',
#        'FiscalMonth', 'OriginalBudget', 'RevisedBudget', 'Actual',
#        'Department', 'DepartmentGroup', 'FunctionDescription', 'FunctionGroup',
#        'FundGroup', 'LTDOriginalBudget', 'LTDRevisedBudget', 'Encumbrance',
#        'ObligatedAmount', 'UnencumberedBalance', 'MultiYear'],
#       dtype='object')

# %% [markdown]
# There are about 500 values in the Revenue column that are <0. Not sure what values less than 0 mean

# %% [markdown]
# Metadata:
# *   Month/Year
# *   Revenue columns('OriginalBudget', 'RevisedBudget', 'Actual')
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: IL
# Municipilaties: None
# Revenue: Contains revenue for each subcategory and total revenue
# Category: Contains subcategories

# %%
effingham_il_df.head(2)
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance MultiYear
# 0  2018-1-1001       1001  ...             12000.0     False
# 1  2018-1-1013       1013  ...             85000.0     False
#
# [2 rows x 47 columns]

# %%
#we need to extract month
filtered_eff['Month number'] = effingham_il_df['FiscalMonth'].astype(str).str[:2]
#effingham_il_df['Year-Month'] = effingham_il_df['FiscalYear'] + '-' + effingham_il_df['Month number']

filtered_eff.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          UniqueId  AccountId  ... MultiYear Month number
# 122  2018-12-1001       1001  ...     False           04
# 123  2018-12-1013       1013  ...     False           04
#
# [2 rows x 48 columns]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = effingham_il_df.groupby(['FiscalYear', 'Month number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(5)
# Out:
#    FiscalYear Month number       Actual
# 0        2018           04  33213984.00
# 1        2018           05         0.00
# 2        2019           04  36908978.28
# 3        2019           05         0.00
# 4        2020           01   1833910.89

# %%
agg_rev_by_month.tail(3)
# Out:
#     FiscalYear Month number      Actual
# 34        2022           10  2160401.56
# 35        2022           11  5281772.80
# 36        2022           12   281783.12

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'].astype(str) + '-' + agg_rev_by_month['Month number'].astype(str)

agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month number      Actual Year-Month
# 0        2018           04  33213984.0    2018-04
# 1        2018           05         0.0    2018-05

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Alexander County, NY (ERP data)

# %%
alexander_ny_df = pd.read_csv('Budgeted_Revenues_Alexander_County_nyc.csv')
alexander_ny_df.head(10)
# Out:
#                AccountDescription  AccountId  ... UnemcumberedBalance     UniqueId
# 0  Maternal Health Local Receipts       1000  ...             3480.00  2018-1-1000
# 1   Maternal Health TXIX Receipts       1001  ...            20555.21  2018-1-1001
# 2                       WIC Funds       1055  ...           102803.57  2018-1-1055
# 3                    Patient Fees       1083  ...            28244.40  2018-1-1083
# 4          Dental Insurance Reimb       1084  ...            83723.41  2018-1-1084
# 5     Dental Health TXIX Receipts       1085  ...           374119.97  2018-1-1085
# 6           Family Planning Funds       1110  ...            76719.00  2018-1-1110
# 7  Family Planning Local Receipts       1112  ...            19586.22  2018-1-1112
# 8   Family Planning TXIX Receipts       1113  ...            32913.40  2018-1-1113
# 9  Communicable Disease State Fds       1139  ...            14164.00  2018-1-1139
#
# [10 rows x 47 columns]

# %%
alexander_ny_df.shape[0]
# Out:
# 11739

# %%
filtered_alexander_ny = alexander_ny_df[alexander_ny_df['Actual'] > 0]
filtered_alexander_ny.shape[0]
# Out:
# 9610

# %%
alexander_ny_df.shape[0] - filtered_alexander_ny.shape[0]
# Out:
# 2129

# %% [markdown]
# EDA:
# Look for columns where obligated amount is not the same as actual amount
# Compare Original Budget to Revised budget and Actual respectively

# %%
alexander_ny_df['FiscalYear'].unique()
#how do they have fiscal year data for 2023 already? Not sure how these makes sense
# Out:
# array([2018, 2019, 2020, 2021, 2022, 2023])

# %%
alexander_ny_df['AccountDescription'].unique()

# %%
alexander_ny_df['AccountType'].unique()

# %%
alexander_ny_df['Object'].unique()

# %%
alexander_ny_df['FiscalMonth'].unique()

# %% [markdown]
# Dates start from July 2017 to February 2022-how do we get dates for february 2022 already?

# %%
alexander_ny_df.columns
# Out:
# Index(['AccountDescription', 'AccountId', 'AccountStatus', 'AccountType',
#        'Actual', 'CharacterCode', 'CharacterCodeDescription', 'Department',
#        'DepartmentGroup', 'Encumbrance', 'Entity', 'FiscalMonth', 'FiscalYear',
#        'FullAccount', 'FunctionDescription', 'FunctionGroup', 'Fund',
#        'FundCode', 'FundGroup', 'LTDOriginalBudget', 'LTDRevisedBudget',
#        'MultiYear', 'Object', 'ObjectCode', 'ObligatedAmount', 'Organization',
#        'OrganizationCode', 'OriginalBudget', 'Project', 'ProjectCode',
#        'RevisedBudget', 'Segment2', 'Segment2Code', 'Segment3', 'Segment3Code',
#        'Segment4', 'Segment4Code', 'Segment5', 'Segment5Code', 'Segment6',
#        'Segment6Code', 'Segment7', 'Segment7Code', 'Segment8', 'Segment8Code',
#        'UnemcumberedBalance', 'UniqueId'],
#       dtype='object')

# %%
alexander_ny_df.dtypes
# Out:
# AccountDescription           object
# AccountId                     int64
# AccountStatus                object
# AccountType                  object
# Actual                      float64
# CharacterCode               float64
# CharacterCodeDescription     object
# Department                  float64
# DepartmentGroup             float64
# Encumbrance                   int64
# Entity                       object
# FiscalMonth                  object
# FiscalYear                    int64
# FullAccount                  object
# FunctionDescription         float64
# FunctionGroup               float64
# Fund                         object
# FundCode                      int64
# FundGroup                    object
# LTDOriginalBudget           float64
# LTDRevisedBudget            float64
# MultiYear                      bool
# Object                       object
# ObjectCode                    int64
# ObligatedAmount             float64
# Organization                 object
# ...

# %%
filtered_alexander_ny.head(2)
# Out:
#                AccountDescription  AccountId  ... UnemcumberedBalance     UniqueId
# 0  Maternal Health Local Receipts       1000  ...             3480.00  2018-1-1000
# 1   Maternal Health TXIX Receipts       1001  ...            20555.21  2018-1-1001
#
# [2 rows x 47 columns]

# %%
filtered_alexander_ny['Month number'] = filtered_alexander_ny.astype(str).str[:2]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_alexander_ny.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']

agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# Columns describing subcategories:
#
# AccountDescription, CharacterCode, AccountType, Object

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from July 2017 to February 2022)
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# * Revenue(ObligatedAmount,
#
# State: NY
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories

# %% [markdown]
# #Beaufort,  South Carolina (ERP)

# %%
Beauf_SC_df = pd.read_csv('Budgeted_Revenues_Beaufort_SC.csv')

Beauf_SC_df.head(10)
# Out:
#   AccountDescription  AccountId  ... Segment8Code       UniqueId
# 0       RETAIL SALES      15399  ...           -1  2019-10-15399
# 1       RETAIL SALES      15399  ...           -1   2019-2-15399
# 2       RETAIL SALES      15399  ...           -1  2021-11-15399
# 3       RETAIL SALES      15399  ...           -1   2020-2-15399
# 4       RETAIL SALES      15399  ...           -1   2019-1-15399
# 5       RETAIL SALES      15399  ...           -1  2019-12-15399
# 6       RETAIL SALES      15399  ...           -1   2018-2-15399
# 7       RETAIL SALES      15399  ...           -1   2018-9-15399
# 8       RETAIL SALES      15399  ...           -1   2020-1-15399
# 9       RETAIL SALES      15399  ...           -1  2019-11-15399
#
# [10 rows x 41 columns]

# %%
Beauf_SC_df.tail(8)
# Out:
#                    AccountDescription  AccountId  ... Segment8Code       UniqueId
# 22790         RENTAL CO PROPERTY- R&C      20278  ...           -1   2022-1-20278
# 22791             FEDERAL GRANT FUNDS      19554  ...           -1   2018-3-19554
# 22792                AUTOMOBILE TAXES      17241  ...           -1   2019-2-17241
# 22793  TRUST FUNDS RECEIVED - SEX OFF      15887  ...           -1  2019-12-15887
# 22794         INTEREST ON INVESTMENTS      17433  ...           -1  2019-12-17433
# 22795          SCDDSN CONTRACT PEYTON      16185  ...           -1   2019-3-16185
# 22796        3% & 7% PENALTIES ON TAX      17138  ...           -1   2020-7-17138
# 22797         MERCHANTS INVENTORY TAX      17095  ...           -1   2019-2-17095
#
# [8 rows x 41 columns]

# %%
Beauf_SC_df.columns

# %%
Beauf_SC_df['FiscalYear'].unique()
# Out:
# array([2019, 2021, 2020, 2018, 2022])

# %%
Beauf_SC_df['FiscalMonth'].unique()
# Out:
# array(['04/01/2019 12:00:00 AM', '08/01/2018 12:00:00 AM',
#        '05/01/2021 12:00:00 AM', '08/01/2019 12:00:00 AM',
#        '07/01/2018 12:00:00 AM', '06/01/2019 12:00:00 AM',
#        '08/01/2017 12:00:00 AM', '03/01/2018 12:00:00 AM',
#        '07/01/2019 12:00:00 AM', '05/01/2019 12:00:00 AM',
#        '11/01/2017 12:00:00 AM', '04/01/2018 12:00:00 AM',
#        '01/01/2019 12:00:00 AM', '12/01/2019 12:00:00 AM',
#        '01/01/2021 12:00:00 AM', '12/01/2020 12:00:00 AM',
#        '10/01/2020 12:00:00 AM', '02/01/2019 12:00:00 AM',
#        '05/01/2018 12:00:00 AM', '11/01/2018 12:00:00 AM',
#        '02/01/2018 12:00:00 AM', '06/01/2020 12:00:00 AM',
#        '08/01/2020 12:00:00 AM', '01/01/2020 12:00:00 AM',
#        '10/01/2017 12:00:00 AM', '11/01/2019 12:00:00 AM',
#        '10/01/2019 12:00:00 AM', '06/01/2018 12:00:00 AM',
#        '07/01/2020 12:00:00 AM', '12/01/2018 12:00:00 AM',
#        '03/01/2019 12:00:00 AM', '03/01/2020 12:00:00 AM',
# ...

# %% [markdown]
# Dates start from July 2017 to june 2022

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from July 2017 to February 2022)
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: NY
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
Beauf_SC_df.head(2)
# Out:
#   AccountDescription  AccountId  ... Segment8Code       UniqueId
# 0       RETAIL SALES      15399  ...           -1  2019-10-15399
# 1       RETAIL SALES      15399  ...           -1   2019-2-15399
#
# [2 rows x 41 columns]

# %%
Beauf_SC_df.shape
# Out:
# (22798, 41)

# %%
filtered_beauf = Beauf_SC_df[Beauf_SC_df['Actual'] > 0]
filtered_beauf.shape
# Out:
# (21150, 41)

# %%
Beauf_SC_df.shape[0] - filtered_beauf.shape[0]
# Out:
# 1648

# %%
filtered_beauf['Month Number'] = filtered_beauf['FiscalMonth'].astype(str).str[:2]
filtered_beauf.head(2)

# %%
agg_rev_by_month = filtered_beauf.groupby(['FiscalYear', 'Month Number'], as_index = False)['Actual'].sum()
agg_rev_by_month.head(2)

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']

agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %% [markdown]
# #Boulder City, Nevada (ERP)

# %%
boulder_nv_df = pd.read_csv('Budgeted_Revenues_Boulder_city_Nevada.csv')
boulder_nv_df.head(10)
# Out:
#           AccountDescription  AccountId  ... UnencumberedBalance MultiYear
# 0      SALES OF FIXED ASSETS       4157  ...             -720.00     False
# 1    ELECTRICAL HOOK-UP FEES       4804  ...            -7750.00     False
# 2         WATER HOOK-UP FEES       5181  ...           -14900.00     False
# 3     RESIDENTIAL CONST. TAX        542  ...            -2000.00     False
# 4         SEWER HOOK-UP FEES       5485  ...            -3900.00     False
# 5        USE OF FUND BALANCE       4425  ...          1996525.00     False
# 6  MISC BUILDING PERMIT FEES        558  ...              -60.00     False
# 7      CRIMES PREVENTION TAX       4598  ...           -18838.85     False
# 8                 AD VALOREM        536  ...           777897.30     False
# 9   INFRASTRUCTURE SALES TAX        539  ...           655047.65     False
#
# [10 rows x 47 columns]

# %%
boulder_nv_df.tail(10)

# %%
boulder_nv_df.columns
# Out:
# Index(['AccountDescription', 'AccountId', 'AccountStatus', 'AccountType',
#        'Actual', 'CharacterCode', 'CharacterCodeDescription', 'Department',
#        'DepartmentGroup', 'Entity', 'FiscalMonth', 'FiscalYear', 'FullAccount',
#        'FunctionDescription', 'FunctionGroup', 'Fund', 'FundCode', 'FundGroup',
#        'Object', 'ObjectCode', 'Organization', 'OrganizationCode',
#        'OriginalBudget', 'Project', 'ProjectCode', 'RevisedBudget', 'Segment2',
#        'Segment2Code', 'Segment3', 'Segment3Code', 'Segment4', 'Segment4Code',
#        'Segment5', 'Segment5Code', 'Segment6', 'Segment6Code', 'Segment7',
#        'Segment7Code', 'Segment8', 'Segment8Code', 'UniqueId',
#        'LTDOriginalBudget', 'LTDRevisedBudget', 'Encumbrance',
#        'ObligatedAmount', 'UnencumberedBalance', 'MultiYear'],
#       dtype='object')

# %%
boulder_nv_df['FiscalYear'].unique()
# Out:
# array([2022, 2018, 2019, 2020, 2021])

# %%
boulder_nv_df['FiscalMonth'].unique()
# Out:
# array(['10/01/2021 12:00:00 AM', '07/01/2017 12:00:00 AM',
#        '09/01/2021 12:00:00 AM', '11/01/2021 12:00:00 AM',
#        '06/01/2019 12:00:00 AM', '04/01/2018 12:00:00 AM',
#        '07/01/2021 12:00:00 AM', '05/01/2018 12:00:00 AM',
#        '06/01/2018 12:00:00 AM', '12/01/2021 12:00:00 AM',
#        '08/01/2017 12:00:00 AM', '07/01/2019 12:00:00 AM',
#        '03/01/2020 12:00:00 AM', '09/01/2017 12:00:00 AM',
#        '08/01/2021 12:00:00 AM', '10/01/2017 12:00:00 AM',
#        '11/01/2017 12:00:00 AM', '12/01/2017 12:00:00 AM',
#        '01/01/2018 12:00:00 AM', '08/01/2019 12:00:00 AM',
#        '07/01/2020 12:00:00 AM', '02/01/2018 12:00:00 AM',
#        '03/01/2018 12:00:00 AM', '07/01/2018 12:00:00 AM',
#        '01/01/2022 12:00:00 AM', '04/01/2019 12:00:00 AM',
#        '05/01/2019 12:00:00 AM', '04/01/2020 12:00:00 AM',
#        '05/01/2020 12:00:00 AM', '06/01/2020 12:00:00 AM',
#        '08/01/2018 12:00:00 AM', '10/01/2019 12:00:00 AM',
# ...

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from September 2017 to June 2022)
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: NV
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
boulder_nv_df.head(2)
# Out:
#         AccountDescription  AccountId  ... UnencumberedBalance MultiYear
# 0    SALES OF FIXED ASSETS       4157  ...              -720.0     False
# 1  ELECTRICAL HOOK-UP FEES       4804  ...             -7750.0     False
#
# [2 rows x 47 columns]

# %%
boulder_nv_df.shape
# Out:
# (10290, 47)

# %%
filtered_boulder_nv['FiscalYear'].unique()
# Out:
# array([2022, 2018, 2019, 2020, 2021])

# %%
filtered_boulder_nv = boulder_nv_df[boulder_nv_df['Actual'] >0 ]
filtered_boulder_nv.shape
#there are 1,189 rows of
# Out:
# (9101, 47)

# %%
filtered_boulder_nv['Month Number'] = filtered_boulder_nv['FiscalMonth'].astype(str).str[:2]
filtered_boulder_nv.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         AccountDescription  AccountId  ... MultiYear Month Number
# 0    SALES OF FIXED ASSETS       4157  ...     False           10
# 1  ELECTRICAL HOOK-UP FEES       4804  ...     False           10
#
# [2 rows x 48 columns]

# %% [markdown]
# Not sure why there is data going up until December 2022.

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_boulder_nv.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number      Actual
# 0        2018           01  5224978.26
# 1        2018           02  7505650.30

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'].astype(str) + '-' + agg_rev_by_month['Month Number'].astype(str)

agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number      Actual Year-Month
# 0        2018           01  5224978.26    2018-01
# 1        2018           02  7505650.30    2018-02

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Boulder, NV',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fdf209a4-31f4-4628-bd45-3591eb48ec10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fdf209a4-31f4-4628-bd45-3591eb48ec10")) {
#                     Plotly.newPlot(
#                         'fdf209a4-31f4-4628-bd45-3591eb48ec10',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month Boulder, NV ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4e31a1ca-cf5a-4331-9b65-03cd9f9c76bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e31a1ca-cf5a-4331-9b65-03cd9f9c76bd")) {
#                     Plotly.newPlot(
#                         '4e31a1ca-cf5a-4331-9b65-03cd9f9c76bd',
# ...

# %%
#grouping by year
agg_Revenues_Yearly = filtered_boulder_nv.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)
# Out:
#    FiscalYear        Actual
# 0        2018  8.456093e+07
# 1        2019  1.097674e+08
# 2        2020  1.222870e+08
# 3        2021  1.192417e+08
# 4        2022  6.752888e+07

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c080a640-d23f-4c01-9d64-572ce6b0a029" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c080a640-d23f-4c01-9d64-572ce6b0a029")) {
#                     Plotly.newPlot(
#                         'c080a640-d23f-4c01-9d64-572ce6b0a029',
# ...

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Centennial, Colorado

# %%
centennial_co_df = pd.read_csv('Budgeted_Revenues_Centennial_CO.csv')
centennial_co_df.head()
# Out:
#           AccountDescription  AccountId  ... UnemcumberedBalance     UniqueId
# 0     Miscellaneous Revenues        478  ...                0.00   2019-1-478
# 1  Intergovernmental - Other        460  ...                0.00   2020-1-460
# 2  Property Taxes - Interest        402  ...               -9.06  2019-10-402
# 3              Passport Fees        443  ...            -4480.00  2019-10-443
# 4  Intergovernmental - Other        460  ...          -617127.99  2018-12-460
#
# [5 rows x 47 columns]

# %%
centennial_co_df.shape
# Out:
# (2251, 47)

# %% [markdown]
# Has lots of 'Actual' values that were less than or equal to 0.

# %%
filtered_centennial_co = centennial_co_df[centennial_co_df['Actual'] > 0]
filtered_centennial_co.shape
# Out:
# (1699, 47)

# %%
centennial_co_df['FiscalYear'].unique()
# Out:
# array([2019, 2020, 2018, 2021, 2022])

# %%
centennial_co_df['FiscalMonth'].unique()

# %% [markdown]
# January 2018 to December 2022

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from January 2018 to December 2022)
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: Colorado
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
filtered_centennial_co.head(2)
# Out:
#           AccountDescription  AccountId  ... UnemcumberedBalance     UniqueId
# 2  Property Taxes - Interest        402  ...               -9.06  2019-10-402
# 3              Passport Fees        443  ...            -4480.00  2019-10-443
#
# [2 rows x 47 columns]

# %%
filtered_centennial_co['Month number'] = filtered_centennial_co['FiscalMonth'].astype(str).str[:2]
filtered_centennial_co.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           AccountDescription  AccountId  ...     UniqueId Month number
# 2  Property Taxes - Interest        402  ...  2019-10-402           10
# 3              Passport Fees        443  ...  2019-10-443           10
#
# [2 rows x 48 columns]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_centennial_co.groupby(['FiscalYear', 'Month number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month number        Actual
# 0        2018           12  1.207599e+08
# 1        2019           09  8.869413e+07

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'].astype(str) + '-' + agg_rev_by_month['Month number'].astype(str)

agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month number        Actual Year-Month
# 0        2018           12  1.207599e+08    2018-12
# 1        2019           09  8.869413e+07    2019-09

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7ddaa68a-3b12-430d-9476-e5a8c0e0fc0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ddaa68a-3b12-430d-9476-e5a8c0e0fc0e")) {
#                     Plotly.newPlot(
#                         '7ddaa68a-3b12-430d-9476-e5a8c0e0fc0e',
# ...

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a51ac7f9-338f-4128-9903-1d27f4b849da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a51ac7f9-338f-4128-9903-1d27f4b849da")) {
#                     Plotly.newPlot(
#                         'a51ac7f9-338f-4128-9903-1d27f4b849da',
# ...

# %%
#grouping by year
agg_Revenues_Yearly = filtered_centennial_co.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)
# Out:
#    FiscalYear        Actual
# 0        2018  1.207599e+08
# 1        2019  1.166530e+08
# 2        2020  1.401606e+08
# 3        2021  8.959190e+07

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f5db235-88d3-4f01-b8b1-ffa008d83833" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f5db235-88d3-4f01-b8b1-ffa008d83833")) {
#                     Plotly.newPlot(
#                         '4f5db235-88d3-4f01-b8b1-ffa008d83833',
# ...

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Champaign, IL (ERP)

# %%
illinois_df = pd.read_csv('Budgeted_Revenues_Champaign_IL.csv')
illinois_df.head(10)
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0  2018-1-1004       1004  ...            22441.00      False
# 1  2018-1-1007       1007  ...            24143.00      False
# 2  2018-1-1009       1009  ...           613263.00      False
# 3  2018-1-1013       1013  ...             1000.00      False
# 4  2018-1-1014       1014  ...          2750700.00      False
# 5  2018-1-1015       1015  ...           518176.87      False
# 6  2018-1-1016       1016  ...           445508.00      False
# 7  2018-1-1019       1019  ...           903400.00      False
# 8  2018-1-1020       1020  ...           517238.00      False
# 9  2018-1-1022       1022  ...           725099.00      False
#
# [10 rows x 47 columns]

# %%
illinois_df['FiscalYear'].unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022])

# %%
illinois_df['FiscalMonth'].unique()
# Out:
# array(['07/01/2017 12:00:00 AM', '04/01/2018 12:00:00 AM',
#        '05/01/2018 12:00:00 AM', '06/01/2018 12:00:00 AM',
#        '08/01/2017 12:00:00 AM', '09/01/2017 12:00:00 AM',
#        '10/01/2017 12:00:00 AM', '11/01/2017 12:00:00 AM',
#        '12/01/2017 12:00:00 AM', '01/01/2018 12:00:00 AM',
#        '02/01/2018 12:00:00 AM', '03/01/2018 12:00:00 AM',
#        '07/01/2018 12:00:00 AM', '04/01/2019 12:00:00 AM',
#        '05/01/2019 12:00:00 AM', '06/01/2019 12:00:00 AM',
#        '08/01/2018 12:00:00 AM', '09/01/2018 12:00:00 AM',
#        '10/01/2018 12:00:00 AM', '11/01/2018 12:00:00 AM',
#        '12/01/2018 12:00:00 AM', '01/01/2019 12:00:00 AM',
#        '02/01/2019 12:00:00 AM', '03/01/2019 12:00:00 AM',
#        '07/01/2019 12:00:00 AM', '04/01/2020 12:00:00 AM',
#        '05/01/2020 12:00:00 AM', '06/01/2020 12:00:00 AM',
#        '08/01/2019 12:00:00 AM', '09/01/2019 12:00:00 AM',
#        '10/01/2019 12:00:00 AM', '11/01/2019 12:00:00 AM',
# ...

# %% [markdown]
# Dates: July 2017 to December 2021

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from July 2017 to December 2021)
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: Colorado
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
illinois_df.head(2)
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0  2018-1-1004       1004  ...             22441.0      False
# 1  2018-1-1007       1007  ...             24143.0      False
#
# [2 rows x 47 columns]

# %%
illinois_df.shape
# Out:
# (11369, 47)

# %%
filtered_champ_il = illinois_df[illinois_df['Actual'] > 0]
filtered_champ_il.shape
# Out:
# (10213, 47)

# %%
illinois_df.shape[0] - filtered_champ_il.shape[0]
# Out:
# 1156

# %%
filtered_champ_il['Month Number'] = filtered_champ_il['FiscalMonth'].astype(str).str[:2]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_champ_il.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']

agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_champ_il.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(3)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Gaitlin, TN (ERP)

# %%
gaitlin_tn_df = pd.read_csv('Budgeted_Revenues_Gaitlin_TN.csv')
gaitlin_tn_df.head(10)
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0  2018-1-1106       1106  ...            15575.00      False
# 1  2018-1-1703       1703  ...         10375000.00      False
# 2  2018-1-1720       1720  ...            77950.34      False
# 3  2018-1-1721       1721  ...            66925.27      False
# 4  2018-1-1722       1722  ...            74483.17      False
# 5  2018-1-1723       1723  ...           780000.00      False
# 6  2018-1-1724       1724  ...           563000.00      False
# 7  2018-1-1725       1725  ...           366000.00      False
# 8  2018-1-1726       1726  ...            72000.00      False
# 9  2018-1-1727       1727  ...          9420485.20      False
#
# [10 rows x 47 columns]

# %%
gaitlin_tn_df.shape
# Out:
# (5730, 47)

# %%
filtered_gaitlin_df = gaitlin_tn_df[gaitlin_tn_df['Actual'] > 0]
filtered_gaitlin_df
# Out:
#          UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0     2018-1-1106       1106  ...            15575.00      False
# 2     2018-1-1720       1720  ...            77950.34      False
# 3     2018-1-1721       1721  ...            66925.27      False
# 4     2018-1-1722       1722  ...            74483.17      False
# 14    2018-1-1753       1753  ...            14541.69      False
# ...           ...        ...  ...                 ...        ...
# 5725  2022-5-2068       2068  ...             8504.19      False
# 5726  2022-5-2097       2097  ...            -2825.54      False
# 5727  2022-5-3803       3803  ...            -3804.42      False
# 5728  2022-5-3981       3981  ...           -28456.50      False
# 5729  2022-6-3601       3601  ...             -250.00      False
#
# [5345 rows x 47 columns]

# %%
gaitlin_tn_df.shape[0] -filtered_gaitlin_df.shape[0]
# Out:
# 385

# %%
gaitlin_tn_df['FiscalYear'].unique()
# Out:
# array([2018, 2019, 2022, 2020, 2021])

# %%
gaitlin_tn_df[gaitlin_tn_df['Actual'] <=0 ].shape
# Out:
# (385, 47)

# %%
gaitlin_tn_df.tail(10)
# Out:
#          UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 5720  2022-5-3802       3802  ...            -6285.90      False
# 5721  2022-3-3083       3083  ...           -86369.66      False
# 5722  2022-6-2017       2017  ...            -1279.90      False
# 5723  2022-5-1721       1721  ...            -2163.37      False
# 5724  2022-5-1723       1723  ...           -81781.63      False
# 5725  2022-5-2068       2068  ...             8504.19      False
# 5726  2022-5-2097       2097  ...            -2825.54      False
# 5727  2022-5-3803       3803  ...            -3804.42      False
# 5728  2022-5-3981       3981  ...           -28456.50      False
# 5729  2022-6-3601       3601  ...             -250.00      False
#
# [10 rows x 47 columns]

# %%
gaitlin_tn_df['Entity'].unique()
# Out:
# array(['City'], dtype=object)

# %%
gaitlin_tn_df['FiscalMonth'].unique()

# %% [markdown]
# Dates: July 2017 to December 2022

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from July 2017 to December 2021) columns: FiscalYear, FiscalMonth,
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: Colorado
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
filtered_gaitlin_df.head(2)
# Out:
#       UniqueId  AccountId  ... UnencumberedBalance  MultiYear
# 0  2018-1-1106       1106  ...            15575.00      False
# 2  2018-1-1720       1720  ...            77950.34      False
#
# [2 rows x 47 columns]

# %%
filtered_gaitlin_df['Month Number'] = filtered_gaitlin_df['FiscalMonth'].astype(str).str[:2]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_gaitlin_df.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']
agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Farmers Branch, TX (ERP)

# %%
import pandas as pd
farmers_branch_tx_df = pd.read_csv('Budgeted_Revenues_farmers_branch_TX.csv')
farmers_branch_tx_df.head(5)
# Out:
#             AccountDescription  AccountId  ... Segment8Code     UniqueId
# 0     CURRENT AD VALOREM TAXES       1138  ...           -1  2018-1-1138
# 1     CURRENT AD VALOREM TAXES       1139  ...           -1  2018-1-1139
# 2  PRIOR YEAR AD VALOREM TAXES       1140  ...           -1  2018-1-1140
# 3  PRIOR YEAR AD VALOREM TAXES       1141  ...           -1  2018-1-1141
# 4                    SALES TAX       1142  ...           -1  2018-1-1142
#
# [5 rows x 41 columns]

# %%
farmers_branch_tx_df.tail(5)
# Out:
#                   AccountDescription  AccountId  ... Segment8Code     UniqueId
# 5665                    BONDS ISSUED       1386  ...           -1  2023-6-1386
# 5666        PREMIUMS ON BONDS ISSUED       1390  ...           -1  2023-6-1390
# 5667                    BONDS ISSUED       2871  ...           -1  2023-6-2871
# 5668        PREMIUMS ON BONDS ISSUED       2872  ...           -1  2023-6-2872
# 5669  TRANSFER IN - NON-DEPARTMENTAL       1356  ...           -1  2023-9-1356
#
# [5 rows x 41 columns]

# %%
farmers_branch_tx_df.shape
# Out:
# (5670, 41)

# %%
filtered_farmers_branch_tx_df = farmers_branch_tx_df[farmers_branch_tx_df['Actual'] > 0]
filtered_farmers_branch_tx_df.shape
# Out:
# (4916, 41)

# %%
5670-4916
# Out:
# 754

# %% [markdown]
# We have 740 rows where the actual values are 0 or less

# %% [markdown]
# Find columns where Original Budget and Revised budget are different-what is the reasoning behind this difference?

# %%
farmers_branch_tx_df['FiscalYear'].unique()
# Out:
# array([2018, 2019, 2020, 2021, 2022, 2023])

# %%
farmers_branch_tx_df['FiscalMonth'].unique()

# %% [markdown]
# October 2017 to June 2023

# %% [markdown]
# Metadata:
# *   Month/Year( Dates start from October 2017 to June 2023) columns: FiscalYear, FiscalMonth,
# *   Subcategorization of sales Tax(columns: Segment2, AccountDescription, Organization)
# *
#
# State: Colorado
# Municipilaties: None
# Revenue: Has Actual column, OriginalBudget, Revised Budget, ObligatedAmount
# Category: Contains subcategories columns: Segment2, AccountDescription, FundOrganization, FundGroup, Object, Organization, Segment3, CharacterCodeDescription

# %%
filtered_farmers_branch_tx_df.head(2)
# Out:
#            AccountDescription  AccountId  ... Segment8Code      UniqueId
# 131  CURRENT AD VALOREM TAXES       1138  ...           -1  2018-12-1138
# 132  CURRENT AD VALOREM TAXES       1139  ...           -1  2018-12-1139
#
# [2 rows x 41 columns]

# %%
filtered_farmers_branch_tx_df.tail(2)
# Out:
#                  AccountDescription  AccountId  ... Segment8Code     UniqueId
# 5654  LOCAL TRUANCY PREVENTION FUND       2844  ...           -1  2022-3-2844
# 5655        MUNICIPAL JURY RECEIPTS       2977  ...           -1  2022-3-2977
#
# [2 rows x 41 columns]

# %% [markdown]
# After filtering the datasets the dates range from September 2018 to Dec 2021

# %%
filtered_farmers_branch_tx_df['Month Number'] = filtered_farmers_branch_tx_df['FiscalMonth'].astype(str).str[:2]
filtered_farmers_branch_tx_df.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            AccountDescription  AccountId  ...      UniqueId Month Number
# 131  CURRENT AD VALOREM TAXES       1138  ...  2018-12-1138           09
# 132  CURRENT AD VALOREM TAXES       1139  ...  2018-12-1139           09
#
# [2 rows x 42 columns]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = filtered_farmers_branch_tx_df.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)
# Out:
#    FiscalYear Month Number        Actual
# 0        2018           09  1.459978e+08
# 1        2019           01  5.813205e+07

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']
agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(10)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
#plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
#plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)

# %% [markdown]
# #Fontana, CA (ERP)

# %%
fontana_ca_df = pd.read_csv('Budgeted_Revenues_fontana.csv')
fontana_ca_df.head(10)

# %%
fontana_ca_df.shape[0]
# Out:
# 15898

# %%
fontana_ca_df.tail(10)

# %% [markdown]
# Dates: July 2017 to December 2021

# %%
fontana_ca_df_filtered  =  fontana_ca_df[fontana_ca_df['Actual'] > 0]
fontana_ca_df_filtered.shape
# Out:
# (11813, 47)

# %%
fontana_ca_df.shape[0] - fontana_ca_df_filtered.shape[0]
# Out:
# 4085

# %% [markdown]
# We have a concerningly large number of rows where the Actual values are less than zero.

# %%
fontana_ca_df_filtered['Month Number'] = fontana_ca_df_filtered['FiscalMonth'].astype(str).str[:2]

# %%
#aggregate the data by [month, year]
agg_rev_by_month = fontana_ca_df_filtered.groupby(['FiscalYear', 'Month Number'], as_index= False)['Actual'].sum()
agg_rev_by_month.head(2)

# %%
agg_rev_by_month['Year-Month'] = agg_rev_by_month['FiscalYear'] + '-' + agg_rev_by_month['Month Number']

agg_rev_by_month.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y=agg_rev_by_month['Actual'],
                        marker_color='indianred', text="Revenue"))
fig.update_layout({"title": 'Sales Tax Revenue by Month Albany New York',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Total Revenues"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
fig = go.Figure(data=go.Bar(x=agg_rev_by_month['Year-Month'].astype(dtype=str), 
                        y= agg_rev_by_month['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Bar Graph of Sales Tax Revenue by Month in Albany ',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})

fig.show()

# %%
#grouping by year
agg_Revenues_Yearly = filtered_albany_df.groupby('FiscalYear', as_index= False)['Actual'].sum()
agg_Revenues_Yearly.head(2)

# %%
import plotly.express as px
import plotly.graph_objs as go
fig = go.Figure(data=go.Scatter(x=agg_Revenues_Yearly['FiscalYear'].astype(dtype=str), 
                        y=agg_Revenues_Yearly['Actual'],
                        marker_color='indianred', text="counts"))
fig.update_layout({"title": 'Sales Tax Revenue by Year',
                   "xaxis": {"title":"Year"},
                   "yaxis": {"title":"Sales Tax Revenue"},
                   "showlegend": False})
#fig.write_image("by-month.png",format="png", width=1000, height=600, scale=3)
fig.show()

# %%
#creating a box plot using Year-month columns
sns.boxplot(x = 'Year-Month', y='Actual', data = agg_rev_by_month)

# %%
#creating a box plot using Years
sns.boxplot(x = 'FiscalYear', y='Actual', data = agg_Revenues_Yearly)

# %%
# plotting with confidence intervals 
sns.lineplot(x="Year-Month", y="Actual", data = agg_rev_by_month)

# %%
# plotting with confidence intervals 
sns.lineplot(x="FiscalYear", y="Actual", data = agg_Revenues_Yearly)
